# %% [markdown]
# # Water consumption

# %% [markdown]
# The current notebook computes an interpolation of temperatures in each pixel based on SIAM extracted data.

# %% [markdown]
# A .bluemix/cos_credentials.json file correctly configured located at home directory is needed in order to connect with IBM Cloud. More information at https://cloud.ibm.com/docs/services/cloud-object-storage/iam?topic=cloud-object-storage-service-credentials.

# %%
from collections import defaultdict
from ibm_botocore.client import Config, ClientError
from geospatial_usecase.io_utils.cos import COS
from geospatial_usecase.io_utils.plot import plot_random_blocks, plot_results
from rasterio.windows import Window
from scipy.spatial import distance_matrix
from shapely.geometry import Point, MultiPoint, box
from pprint import pprint

import os
import ibm_boto3
import math
import numpy as np
import pandas as pd
import lithops
import requests
import rasterio
import json
import random

from lithops import Storage

# %% [markdown]
# ## Global parameters

# %% [markdown]
# Area outside the processed tile that we want to consider for taking SIAM stations into account:

# %%
AREA_OF_INFLUENCE = 4000

# %% [markdown]
# IBM Cos bucket to upload files:

# %%
BUCKET = 'geospatial-usecase'

# %% [markdown]
# Runtime name

# %%
RUNTIME = 'jsampe/lithops-k8s-geospatial'

# %% [markdown]
# Split tile into SPLITS$^2$ chunks:

# %%
SPLITS = 3

# %% [markdown]
# Correlation coefficient between elevation and temperature:

# %%
r = -0.0056

# %% [markdown]
# Elevation to interpolate temperature:

# %%
zdet = 2000

# %% [markdown]
# Day of year to calculate solar irradiation:

# %%
DAY_OF_YEAR = 50

# %% [markdown]
# Object storage key prefix, to keep objects organized:

# %%
cloud_storage = Storage(backend="ceph")

# %% [markdown]
# ## Serverless computation

# %% [markdown]
# Input MDT tiles to process:

# %%
tiles = [os.path.splitext(os.path.basename(key))[0]
         for key in cloud_storage.list_keys(bucket=BUCKET, prefix='MDT')]
tiles
# Out:
# ['PNOA_MDT05_ETRS89_HU30_0891_LID',
#  'PNOA_MDT05_ETRS89_HU30_0892_LID',
#  'PNOA_MDT05_ETRS89_HU30_0912_LID',
#  'PNOA_MDT05_ETRS89_HU30_0913_LID',
#  'PNOA_MDT05_ETRS89_HU30_0933_LID',
#  'PNOA_MDT05_ETRS89_HU30_0934_LID',
#  'PNOA_MDT05_ETRS89_HU30_0954_LID',
#  'PNOA_MDT05_ETRS89_HU30_0955_LID']

# %%
# DEBUG
#tiles = ['PNOA_MDT05_ETRS89_HU30_0891_LID','PNOA_MDT05_ETRS89_HU30_0892_LID']
#tiles

# %% [markdown]
# Compute solar irradiation given a day of year using GRASS libraries:

# %%
def compute_solar_irradiation(inputFile, outputFile, crs='32630'):
    # Define grass working set
    GRASS_GISDB = 'grassdata'
    GRASS_LOCATION = 'GEOPROCESSING'
    GRASS_MAPSET = 'PERMANENT'
    GRASS_ELEVATIONS_FILENAME = 'ELEVATIONS'
    
    import os
    import shutil
    os.environ['GRASSBIN'] = 'grass76'
    from grass_session import Session
    import grass.script as gscript
    from grass.pygrass.modules.shortcuts import general as g
    from grass.pygrass.modules.shortcuts import raster as r
    import re
    os.environ.update(dict(GRASS_COMPRESS_NULLS='1'))
    
    # Clean previously processed data
    if os.path.isdir(GRASS_GISDB):
        shutil.rmtree(GRASS_GISDB)
    with Session(gisdb=GRASS_GISDB, location=GRASS_LOCATION, mapset=GRASS_MAPSET, create_opts='EPSG:32630') as ses:
    
        # Set project projection to match elevation raster projection
        g.proj(epsg=crs, flags='c') 
    
        # Load raster file into working directory
        r.import_(input=inputFile, 
                  output=GRASS_ELEVATIONS_FILENAME, 
                  flags='o')    
        
        # Set project region to match raster region
        g.region(raster=GRASS_ELEVATIONS_FILENAME, flags='s')    
        # Calculate solar irradiation
        gscript.run_command('r.slope.aspect', elevation=GRASS_ELEVATIONS_FILENAME,
                            slope='slope', aspect='aspect')
        gscript.run_command('r.sun', elevation=GRASS_ELEVATIONS_FILENAME,
                            slope='slope', aspect='aspect', beam_rad='beam',
                            step=1, day=DAY_OF_YEAR)
        
        # Get extraterrestrial irradiation from history metadata
        regex = re.compile(r'\d+\.\d+')
        output = gscript.read_command("r.info", flags="h", map=["beam"])
        splits = str(output).split('\n')
        line = next(filter(lambda line: 'Extraterrestrial' in line, splits))
        extraterrestrial_irradiance = float(regex.search(line)[0])
        
        # Export generated results into a GeoTiff file
        if os.path.isfile(outputFile):
            os.remove(outputFile)
            
        r.out_gdal(input='beam', output=outputFile)
        
        return extraterrestrial_irradiance

# %% [markdown]
# Get stations contained in the area of interest:

# %%
def filter_stations(bounds, stations):
    total_points = MultiPoint([Point(x,y) for x, y in stations[['X', 'Y']].to_numpy()])
    intersection = bounds.buffer(AREA_OF_INFLUENCE).intersection(total_points)
    
    return stations[[ intersection.contains(point) for point in total_points]]

# %% [markdown]
# Inverse Distance Weighting interpolation:

# %%
def compute_basic_interpolation(shape, stations, field_value, offset = (0,0)):
    station_pixels = [[pixel[0], pixel[1]] for pixel in stations['pixel'].to_numpy()]
    
    # Get an array where each position represents pixel coordinates
    tile_pixels = np.indices(shape).transpose(1,2,0).reshape(shape[0]*shape[1], 2) + offset
    dist = distance_matrix(station_pixels, tile_pixels)
    weights = np.where(dist == 0, np.finfo('float32').max, 1.0 / dist )
    weights /=  weights.sum(axis=0)
    
    return np.dot(weights.T, stations[field_value].to_numpy()).reshape(shape).astype('float32')

# %% [markdown]
# Interpolate temperatures from a subset of the tile:

# %%
def radiation_interpolation(obj, block_x, block_y, splits, storage):
    tile_key = os.path.basename(obj.key)
    tile_id, _ = os.path.splitext(tile_key)
    
    with rasterio.open(obj.data_stream) as src:
        transform = src.transform
        
        # Compute working window
        step_w = src.width / splits
        step_h = src.height / splits
        
        offset_h = round(step_h * block_x)
        offset_w = round(step_w * block_y)
        
        profile = src.profile
        width = math.ceil(step_w * (block_y + 1) - offset_w)
        height = math.ceil(step_h * (block_x + 1) - offset_h)
        
        profile.update(width=width)
        profile.update(height=height)
        
        window = Window(offset_w, offset_h, width, height)
        
        with rasterio.open('input', 'w', **profile) as dest:
            dest.write(src.read(window=window))
        
    # Stores global irradiation at "output", it also returns extraterrestrial irradiation
    extraterrestrial_irradiation = compute_solar_irradiation('input', 'output')
        
    # Create and store a raster with extraterrestrial_irradiation
    with rasterio.open('extr', 'w', **profile) as dest:
        data = np.full((height, width), extraterrestrial_irradiation, dtype='float32')
        dest.write(data, 1)
        
    out_key = os.path.join('tmp', 'extrad', tile_id, f'chunk_{block_x}-{block_y}') + '.tif'
    with open('extr', 'rb') as out_file:
        storage.put_object(BUCKET, out_key, out_file)
    
    out_key = os.path.join('tmp', 'rad', tile_id, f'chunk_{block_x}-{block_y}') + '.tif'
    with open('output', 'rb') as out_file:
        storage.put_object(BUCKET, out_key, out_file)
    
    return out_key

# %%
def map_interpolation(obj, block_x, block_y, splits, data_field, storage):
    import io
    import math
    import numpy as np
    
    tile_key = os.path.basename(obj.key)
    tile_id, _ = os.path.splitext(tile_key)
          
    siam_stream = storage.get_object(BUCKET, 'siam.csv', stream=True)
    siam = pd.read_csv(siam_stream)
    
    with rasterio.open(obj.data_stream) as src:
        transform = src.transform
        
        # Compute working window
        step_w = src.width / splits
        step_h = src.height / splits
        
        offset_h = round(step_h * block_x)
        offset_w = round(step_w * block_y)
        
        profile = src.profile
        
        width = math.ceil(step_w * (block_y + 1) - offset_w)
        height = math.ceil(step_h * (block_x + 1) - offset_h)
        
        profile.update(width=width)
        profile.update(height=height)
        
        window = Window(offset_w,offset_h, width, height)
        
        # Filter desired stations
        bounding_rect = box(src.bounds.left, src.bounds.top, src.bounds.right, src.bounds.bottom)
        filtered = pd.DataFrame(filter_stations(bounding_rect, siam))
        filtered['pixel'] = filtered.apply(
            lambda station: rasterio.transform.rowcol(transform, station['X'], station['Y']), axis=1)
        
        # Interpolate and write results 
        with rasterio.open('output', 'w', **profile) as dest:
            if data_field == 'temp':
                elevations = src.read(1, window=window) # Get elevations content
                interpolation = compute_basic_interpolation(elevations.shape, filtered,
                                                            'tdet', (offset_h, offset_w))
                interpolation += r * (elevations - zdet)
                dest.write(np.where(elevations == src.nodata, np.nan, interpolation), 1)
            else:
                interpolation = compute_basic_interpolation((height, width),
                                                            filtered, 
                                                            'hr' if data_field == 'humi' else 'v', 
                                                            (offset_h, offset_w))
                dest.write(interpolation, 1)

    # Export results to storage
    out_key = os.path.join('tmp', data_field, tile_id, 'chunk_{}-{}'.format(block_x, block_y)) + '.tif'
    with open('output', 'rb') as output_file:
        storage.put_object(BUCKET, out_key, output_file)
    
    return out_key

# %% [markdown]
# Lithops serverless computation:

# %%
lith = lithops.FunctionExecutor(backend='k8s', storage='ceph', runtime=RUNTIME, log_level="DEBUG")
# Out:
# 2021-07-01 22:18:16,273 [INFO] lithops.config -- Lithops v2.3.5.dev2
# 2021-07-01 22:18:16,275 [DEBUG] lithops.config -- Loading configuration from /home/jovyan/work/.lithops_config
# 2021-07-01 22:18:16,282 [DEBUG] lithops.config -- Loading Serverless backend module: k8s
# 2021-07-01 22:18:16,649 [DEBUG] lithops.config -- Loading Storage backend module: ceph
# 2021-07-01 22:18:16,650 [DEBUG] lithops.storage.backends.ceph.ceph -- Creating Ceph client
# 2021-07-01 22:18:16,651 [DEBUG] lithops.storage.backends.ceph.ceph -- Seting Ceph endpoint to http://10.24.17.56:7480
# 2021-07-01 22:18:16,652 [DEBUG] lithops.storage.backends.ceph.ceph -- Using access_key and secret_key
# 2021-07-01 22:18:16,660 [INFO] lithops.storage.backends.ceph.ceph -- Ceph Storage client created - Endpoint: http://10.24.17.56:7480
# 2021-07-01 22:18:16,662 [DEBUG] lithops.serverless.backends.k8s.k8s -- Creating Kubernetes Job client
# 2021-07-01 22:18:16,737 [DEBUG] lithops.serverless.backends.k8s.k8s -- Set namespace to default
# 2021-07-01 22:18:16,739 [DEBUG] lithops.serverless.backends.k8s.k8s -- Set cluster to kubernetes
# 2021-07-01 22:18:16,740 [INFO] lithops.serverless.backends.k8s.k8s -- Kubernetes Job client created - Namespace: default
# 2021-07-01 22:18:16,741 [DEBUG] lithops.invokers -- ExecutorID 51da88-0 - Total workers: 200
# 2021-07-01 22:18:16,742 [INFO] lithops.executors -- Function executor for k8s created with ID: 51da88-0

# %%
iterdata = [('ceph://{}/MDT/{}.tif'.format(BUCKET, tile), i, j) 
            for i in range(SPLITS) for j in range(SPLITS) for tile in tiles]

# %%
pprint(iterdata)
print('Total functions: {} tiles * ({}^2) splits * 4 calculations = {}'.format(
    len(tiles), SPLITS, len(iterdata) * 4))
# Out:
# [('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif', 0, 0),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif', 0, 0),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif', 0, 0),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif', 0, 0),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif', 0, 0),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif', 0, 0),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif', 0, 0),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif', 0, 0),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif', 0, 1),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif', 0, 1),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif', 0, 1),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif', 0, 1),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif', 0, 1),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif', 0, 1),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif', 0, 1),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif', 0, 1),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif', 0, 2),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif', 0, 2),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif', 0, 2),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif', 0, 2),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif', 0, 2),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif', 0, 2),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif', 0, 2),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif', 0, 2),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif', 1, 0),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif', 1, 0),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif', 1, 0),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif', 1, 0),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif', 1, 0),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif', 1, 0),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif', 1, 0),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif', 1, 0),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif', 1, 1),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif', 1, 1),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif', 1, 1),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif', 1, 1),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif', 1, 1),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif', 1, 1),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif', 1, 1),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif', 1, 1),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif', 1, 2),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif', 1, 2),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif', 1, 2),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif', 1, 2),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif', 1, 2),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif', 1, 2),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif', 1, 2),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif', 1, 2),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif', 2, 0),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif', 2, 0),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif', 2, 0),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif', 2, 0),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif', 2, 0),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif', 2, 0),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif', 2, 0),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif', 2, 0),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif', 2, 1),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif', 2, 1),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif', 2, 1),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif', 2, 1),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif', 2, 1),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif', 2, 1),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif', 2, 1),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif', 2, 1),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif', 2, 2),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif', 2, 2),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif', 2, 2),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif', 2, 2),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif', 2, 2),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif', 2, 2),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif', 2, 2),
#  ('ceph://geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif', 2, 2)]
# Total functions: 8 tiles * (3^2) splits * 4 calculations = 288

# %%
fut = lith.map(radiation_interpolation, iterdata, extra_args=(SPLITS,), runtime_memory=2048)
# Out:
# 2021-07-01 22:18:36,993 [INFO] lithops.invokers -- ExecutorID 51da88-0 | JobID M000 - Selected Runtime: jsampe/lithops-k8s-geospatial - 2048MB
# 2021-07-01 22:18:36,996 [DEBUG] lithops.storage.storage -- Runtime metadata not found in local cache. Retrieving it from storage
# 2021-07-01 22:18:36,997 [DEBUG] lithops.storage.storage -- Trying to download runtime metadata from: ceph://lithops-cloudbutton/lithops.runtimes/2.3.5.dev2/k8s/default/jsampe--lithops-k8s-geospatial--256mb.meta.json
# 2021-07-01 22:18:37,017 [DEBUG] lithops.storage.storage -- Runtime metadata not found in storage
# 2021-07-01 22:18:37,018 [INFO] lithops.invokers -- Runtime jsampe/lithops-k8s-geospatial with 2048MB is not yet installed
# 2021-07-01 22:18:37,019 [INFO] lithops.serverless.backends.k8s.k8s -- Extracting Python modules from: jsampe/lithops-k8s-geospatial
# 2021-07-01 22:18:37,281 [DEBUG] lithops.serverless.backends.k8s.k8s -- Waiting for runtime metadata
# 2021-07-01 22:18:37,291 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-01 22:18:37,511 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-01 22:18:47,300 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-01 22:18:57,307 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-01 22:19:07,312 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-01 22:19:15,998 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-01 22:19:16,000 [DEBUG] lithops.serverless.backends.k8s.k8s -- Runtime metadata generated successfully
# 2021-07-01 22:19:16,145 [DEBUG] lithops.storage.storage -- Uploading runtime metadata to: ceph://lithops-cloudbutton/lithops.runtimes/2.3.5.dev2/k8s/default/jsampe--lithops-k8s-geospatial--256mb.meta.json
# 2021-07-01 22:19:16,190 [DEBUG] lithops.storage.backends.ceph.ceph -- PUT Object lithops.runtimes/2.3.5.dev2/k8s/default/jsampe--lithops-k8s-geospatial--256mb.meta.json - Size: 7.1KiB - OK
# 2021-07-01 22:19:16,192 [DEBUG] lithops.storage.storage -- Storing runtime metadata into local cache: /home/jovyan/.lithops/cache/lithops.runtimes/2.3.5.dev2/k8s/default/jsampe--lithops-k8s-geospatial--256mb.meta.json
# 2021-07-01 22:19:16,197 [DEBUG] lithops.job.job -- ExecutorID 51da88-0 | JobID M000 - Calling map on partitions from object storage flow
# 2021-07-01 22:19:16,198 [DEBUG] lithops.job.partitioner -- Parsing input data
# 2021-07-01 22:19:16,200 [DEBUG] lithops.job.partitioner -- Listing objects in 'ceph://geospatial-usecase/MDT'
# 2021-07-01 22:19:16,213 [DEBUG] lithops.job.partitioner -- Total objects found: 8
# 2021-07-01 22:19:16,214 [DEBUG] lithops.job.partitioner -- Chunk size and chunk number not set
# 2021-07-01 22:19:16,215 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:16,216 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:16,217 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:16,218 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:16,218 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:16,219 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:16,220 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:16,221 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:16,222 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:16,223 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:16,224 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:16,225 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:16,225 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:16,226 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:16,226 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:16,227 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:16,227 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:16,228 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:16,229 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:16,229 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:16,230 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:16,230 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:16,231 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:16,231 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:16,232 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:16,232 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:16,233 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:16,234 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:16,234 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:16,235 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:16,235 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:16,236 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:16,237 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:16,237 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:16,238 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:16,239 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:16,240 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:16,241 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:16,242 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:16,242 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:16,243 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:16,244 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:16,245 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:16,246 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:16,247 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:16,247 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:16,248 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:16,249 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:16,249 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:16,250 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:16,250 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:16,251 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:16,251 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:16,252 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:16,253 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:16,253 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:16,254 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:16,254 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:16,255 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:16,255 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:16,256 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:16,257 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:16,257 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:16,258 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:16,258 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:16,259 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:16,259 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:16,260 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:16,261 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:16,266 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:16,275 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:16,276 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:16,276 [DEBUG] lithops.job.job -- ExecutorID 51da88-0 | JobID M000 - Serializing function and data
# 2021-07-01 22:19:16,430 [DEBUG] lithops.job.serialize -- Referenced modules: /opt/conda/lib/python3.8/site-packages/lithops/storage/utils.py, /opt/conda/lib/python3.8/lib-dynload/math.cpython-38-x86_64-linux-gnu.so, /opt/conda/lib/python3.8/re.py, /opt/conda/lib/python3.8/site-packages/grass_session/__init__.py, /opt/conda/lib/python3.8/site-packages/numpy/__init__.py, /opt/conda/lib/python3.8/os.py, /opt/conda/lib/python3.8/shutil.py, /opt/conda/lib/python3.8/site-packages/rasterio/windows.py, /opt/conda/lib/python3.8/site-packages/rasterio/__init__.py
# 2021-07-01 22:19:16,432 [DEBUG] lithops.job.serialize -- Modules to transmit: None
# 2021-07-01 22:19:16,433 [INFO] lithops.job.job -- ExecutorID 51da88-0 | JobID M000 - Uploading function and data - Total: 20.6KiB
# 2021-07-01 22:19:16,470 [DEBUG] lithops.storage.backends.ceph.ceph -- PUT Object lithops.jobs/51da88-0-M000/aggdata.pickle - Size: 17.3KiB - OK
# GRASSBIN: grass74
# GISBASE: /usr/lib/grass78
# 2021-07-01 22:19:16,502 [DEBUG] lithops.storage.backends.ceph.ceph -- PUT Object lithops.jobs/51da88-0-M000/func.pickle - Size: 3.3KiB - OK
# 2021-07-01 22:19:16,504 [INFO] lithops.invokers -- ExecutorID 51da88-0 | JobID M000 - Starting function invocation: radiation_interpolation() - Total: 72 activations
# 2021-07-01 22:19:16,506 [DEBUG] lithops.invokers -- ExecutorID 51da88-0 | JobID M000 - Chunksize: 1 - Worker processes: 1
# 2021-07-01 22:19:16,509 [DEBUG] lithops.util.metrics -- Sending metric "job_total_calls 72" to http://77.231.202.2:30091/metrics/job/lithops/instance/51da88/job_id/51da88-0-M000/function_name/radiation_interpolation
# 2021-07-01 22:19:16,569 [DEBUG] lithops.serverless.backends.k8s.k8s -- ExecutorID 51da88-0 | JobID M000 - Going to run 72 activations in 72 workers
# 2021-07-01 22:19:16,585 [DEBUG] lithops.invokers -- ExecutorID 51da88-0 | JobID M000 - Job invoked (0.061s) - Activation ID: lithops-51da88-0-m000
# 2021-07-01 22:19:16,587 [INFO] lithops.invokers -- ExecutorID 51da88-0 | JobID M000 - View execution logs at /tmp/lithops/logs/51da88-0-M000.log
# 2021-07-01 22:19:16,590 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M000 - Starting Storage job monitor
# 2021-07-01 22:19:16,608 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M000 - Pending: 72 - Running: 0 - Done: 0

# %%
fut = lith.map(map_interpolation, iterdata, extra_args=(SPLITS,'temp'), runtime_memory=2048)
# Out:
# 2021-07-01 22:19:16,616 [INFO] lithops.invokers -- ExecutorID 51da88-0 | JobID M001 - Selected Runtime: jsampe/lithops-k8s-geospatial - 2048MB
# 2021-07-01 22:19:16,618 [DEBUG] lithops.storage.storage -- Runtime metadata found in local cache
# 2021-07-01 22:19:16,622 [DEBUG] lithops.job.job -- ExecutorID 51da88-0 | JobID M001 - Calling map on partitions from object storage flow
# 2021-07-01 22:19:16,623 [DEBUG] lithops.job.partitioner -- Parsing input data
# 2021-07-01 22:19:16,625 [DEBUG] lithops.job.partitioner -- Listing objects in 'ceph://geospatial-usecase/MDT'
# 2021-07-01 22:19:16,640 [DEBUG] lithops.job.partitioner -- Total objects found: 8
# 2021-07-01 22:19:16,641 [DEBUG] lithops.job.partitioner -- Chunk size and chunk number not set
# 2021-07-01 22:19:16,642 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:16,645 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:16,646 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:16,647 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:16,648 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:16,649 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:16,651 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:16,652 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:16,652 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:16,653 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:16,654 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:16,655 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:16,655 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:16,656 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:16,657 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:16,657 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:16,658 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:16,659 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:16,659 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:16,660 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:16,661 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:16,664 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:16,665 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:16,666 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:16,666 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:16,667 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:16,667 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:16,668 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:16,669 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:16,669 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:16,670 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:16,670 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:16,671 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:16,671 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:16,672 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:16,673 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:16,673 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:16,674 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:16,674 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:16,675 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:16,675 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:16,676 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:16,677 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:16,677 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:16,678 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:16,678 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:16,679 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:16,679 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:16,680 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:16,681 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:16,681 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:16,682 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:16,682 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:16,683 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:16,684 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:16,684 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:16,685 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:16,685 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:16,686 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:16,687 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:16,687 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:16,688 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:16,689 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:16,689 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:16,690 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:16,690 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:16,691 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:16,692 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:16,692 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:16,693 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:16,693 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:16,694 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:16,695 [DEBUG] lithops.job.job -- ExecutorID 51da88-0 | JobID M001 - Serializing function and data
# 2021-07-01 22:19:16,795 [DEBUG] lithops.job.serialize -- Referenced modules: /opt/conda/lib/python3.8/site-packages/shapely/geometry/polygon.py, /opt/conda/lib/python3.8/lib-dynload/math.cpython-38-x86_64-linux-gnu.so, /opt/conda/lib/python3.8/site-packages/lithops/storage/utils.py, /opt/conda/lib/python3.8/site-packages/shapely/geometry/multipoint.py, /opt/conda/lib/python3.8/io.py, /opt/conda/lib/python3.8/site-packages/numpy/__init__.py, /opt/conda/lib/python3.8/site-packages/shapely/geometry/geo.py, /opt/conda/lib/python3.8/site-packages/scipy/spatial/kdtree.py, /opt/conda/lib/python3.8/os.py, /opt/conda/lib/python3.8/site-packages/pandas/__init__.py, /opt/conda/lib/python3.8/site-packages/rasterio/windows.py, /opt/conda/lib/python3.8/site-packages/rasterio/__init__.py
# 2021-07-01 22:19:16,796 [DEBUG] lithops.job.serialize -- Modules to transmit: None
# 2021-07-01 22:19:16,797 [INFO] lithops.job.job -- ExecutorID 51da88-0 | JobID M001 - Uploading function and data - Total: 22.2KiB
# 2021-07-01 22:19:16,825 [DEBUG] lithops.storage.backends.ceph.ceph -- PUT Object lithops.jobs/51da88-0-M001/aggdata.pickle - Size: 18.7KiB - OK
# 2021-07-01 22:19:16,856 [DEBUG] lithops.storage.backends.ceph.ceph -- PUT Object lithops.jobs/51da88-0-M001/func.pickle - Size: 3.5KiB - OK
# 2021-07-01 22:19:16,858 [INFO] lithops.invokers -- ExecutorID 51da88-0 | JobID M001 - Starting function invocation: map_interpolation() - Total: 72 activations
# 2021-07-01 22:19:16,859 [DEBUG] lithops.invokers -- ExecutorID 51da88-0 | JobID M001 - Chunksize: 1 - Worker processes: 1
# 2021-07-01 22:19:16,862 [DEBUG] lithops.util.metrics -- Sending metric "job_total_calls 72" to http://77.231.202.2:30091/metrics/job/lithops/instance/51da88/job_id/51da88-0-M001/function_name/map_interpolation
# 2021-07-01 22:19:17,015 [DEBUG] lithops.serverless.backends.k8s.k8s -- ExecutorID 51da88-0 | JobID M001 - Going to run 72 activations in 72 workers
# 2021-07-01 22:19:17,106 [DEBUG] lithops.invokers -- ExecutorID 51da88-0 | JobID M001 - Job invoked (0.232s) - Activation ID: lithops-51da88-0-m001
# 2021-07-01 22:19:17,107 [INFO] lithops.invokers -- ExecutorID 51da88-0 | JobID M001 - View execution logs at /tmp/lithops/logs/51da88-0-M001.log
# 2021-07-01 22:19:17,110 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M001 - Starting Storage job monitor
# 2021-07-01 22:19:17,124 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M001 - Pending: 72 - Running: 0 - Done: 0

# %%
fut = lith.map(map_interpolation, iterdata, extra_args=(SPLITS,'humi'), runtime_memory=2048)
# Out:
# 2021-07-01 22:19:17,127 [INFO] lithops.invokers -- ExecutorID 51da88-0 | JobID M002 - Selected Runtime: jsampe/lithops-k8s-geospatial - 2048MB
# 2021-07-01 22:19:17,129 [DEBUG] lithops.storage.storage -- Runtime metadata found in local cache
# 2021-07-01 22:19:17,133 [DEBUG] lithops.job.job -- ExecutorID 51da88-0 | JobID M002 - Calling map on partitions from object storage flow
# 2021-07-01 22:19:17,134 [DEBUG] lithops.job.partitioner -- Parsing input data
# 2021-07-01 22:19:17,135 [DEBUG] lithops.job.partitioner -- Listing objects in 'ceph://geospatial-usecase/MDT'
# 2021-07-01 22:19:17,147 [DEBUG] lithops.job.partitioner -- Total objects found: 8
# 2021-07-01 22:19:17,148 [DEBUG] lithops.job.partitioner -- Chunk size and chunk number not set
# 2021-07-01 22:19:17,149 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:17,150 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:17,150 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:17,151 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:17,151 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:17,152 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:17,152 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:17,153 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:17,154 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:17,155 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:17,156 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:17,156 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:17,157 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:17,157 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:17,158 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:17,159 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:17,159 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:17,160 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:17,160 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:17,161 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:17,161 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:17,162 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:17,163 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:17,163 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:17,164 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:17,164 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:17,165 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:17,166 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:17,166 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:17,167 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:17,168 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:17,168 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:17,169 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:17,169 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:17,170 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:17,171 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:17,171 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:17,172 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:17,172 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:17,173 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:17,174 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:17,174 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:17,175 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:17,175 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:17,176 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:17,176 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:17,177 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:17,178 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:17,178 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:17,179 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:17,179 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:17,180 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:17,180 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:17,181 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:17,182 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:17,182 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:17,183 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:17,183 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:17,184 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:17,184 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:17,185 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:17,186 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:17,186 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:17,187 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:17,187 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:17,188 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:17,189 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:17,189 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:17,190 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:17,190 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:17,191 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:17,192 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:17,192 [DEBUG] lithops.job.job -- ExecutorID 51da88-0 | JobID M002 - Serializing function and data
# 2021-07-01 22:19:17,278 [DEBUG] lithops.job.serialize -- Referenced modules: /opt/conda/lib/python3.8/site-packages/shapely/geometry/polygon.py, /opt/conda/lib/python3.8/lib-dynload/math.cpython-38-x86_64-linux-gnu.so, /opt/conda/lib/python3.8/site-packages/lithops/storage/utils.py, /opt/conda/lib/python3.8/site-packages/shapely/geometry/multipoint.py, /opt/conda/lib/python3.8/io.py, /opt/conda/lib/python3.8/site-packages/numpy/__init__.py, /opt/conda/lib/python3.8/site-packages/shapely/geometry/geo.py, /opt/conda/lib/python3.8/site-packages/scipy/spatial/kdtree.py, /opt/conda/lib/python3.8/os.py, /opt/conda/lib/python3.8/site-packages/pandas/__init__.py, /opt/conda/lib/python3.8/site-packages/rasterio/windows.py, /opt/conda/lib/python3.8/site-packages/rasterio/__init__.py
# 2021-07-01 22:19:17,279 [DEBUG] lithops.job.serialize -- Modules to transmit: None
# 2021-07-01 22:19:17,280 [INFO] lithops.job.job -- ExecutorID 51da88-0 | JobID M002 - Uploading function and data - Total: 22.2KiB
# 2021-07-01 22:19:17,361 [DEBUG] lithops.storage.backends.ceph.ceph -- PUT Object lithops.jobs/51da88-0-M002/aggdata.pickle - Size: 18.7KiB - OK
# 2021-07-01 22:19:17,614 [DEBUG] lithops.storage.backends.ceph.ceph -- PUT Object lithops.jobs/51da88-0-M002/func.pickle - Size: 3.5KiB - OK
# 2021-07-01 22:19:17,616 [INFO] lithops.invokers -- ExecutorID 51da88-0 | JobID M002 - Starting function invocation: map_interpolation() - Total: 72 activations
# 2021-07-01 22:19:17,617 [DEBUG] lithops.invokers -- ExecutorID 51da88-0 | JobID M002 - Chunksize: 1 - Worker processes: 1
# 2021-07-01 22:19:17,618 [DEBUG] lithops.util.metrics -- Sending metric "job_total_calls 72" to http://77.231.202.2:30091/metrics/job/lithops/instance/51da88/job_id/51da88-0-M002/function_name/map_interpolation
# 2021-07-01 22:19:17,665 [DEBUG] lithops.serverless.backends.k8s.k8s -- ExecutorID 51da88-0 | JobID M002 - Going to run 72 activations in 72 workers
# 2021-07-01 22:19:17,714 [DEBUG] lithops.invokers -- ExecutorID 51da88-0 | JobID M002 - Job invoked (0.086s) - Activation ID: lithops-51da88-0-m002
# 2021-07-01 22:19:17,715 [INFO] lithops.invokers -- ExecutorID 51da88-0 | JobID M002 - View execution logs at /tmp/lithops/logs/51da88-0-M002.log
# 2021-07-01 22:19:17,720 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M002 - Starting Storage job monitor
# 2021-07-01 22:19:17,737 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M002 - Pending: 72 - Running: 0 - Done: 0

# %%
fut = lith.map(map_interpolation, iterdata, extra_args=(SPLITS,'wind'), runtime_memory=2048)
# Out:
# 2021-07-01 22:19:17,745 [INFO] lithops.invokers -- ExecutorID 51da88-0 | JobID M003 - Selected Runtime: jsampe/lithops-k8s-geospatial - 2048MB
# 2021-07-01 22:19:17,749 [DEBUG] lithops.storage.storage -- Runtime metadata found in local cache
# 2021-07-01 22:19:17,753 [DEBUG] lithops.job.job -- ExecutorID 51da88-0 | JobID M003 - Calling map on partitions from object storage flow
# 2021-07-01 22:19:17,754 [DEBUG] lithops.job.partitioner -- Parsing input data
# 2021-07-01 22:19:17,755 [DEBUG] lithops.job.partitioner -- Listing objects in 'ceph://geospatial-usecase/MDT'
# 2021-07-01 22:19:17,766 [DEBUG] lithops.job.partitioner -- Total objects found: 8
# 2021-07-01 22:19:17,768 [DEBUG] lithops.job.partitioner -- Chunk size and chunk number not set
# 2021-07-01 22:19:17,768 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:17,769 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:17,770 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:17,770 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:17,771 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:17,772 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:17,772 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:17,773 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:17,773 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:17,774 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:17,775 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:17,775 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:17,776 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:17,776 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:17,777 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:17,777 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:17,778 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:17,779 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:17,779 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:17,780 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:17,780 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:17,781 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:17,782 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:17,782 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:17,783 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:17,784 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:17,784 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:17,785 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:17,785 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:17,786 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:17,787 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:17,787 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:17,788 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:17,788 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:17,789 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:17,789 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:17,790 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:17,791 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:17,791 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:17,792 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:17,792 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:17,793 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:17,793 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:17,794 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:17,795 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:17,795 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:17,796 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:17,796 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:17,797 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:17,798 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:17,798 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:17,799 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:17,799 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:17,800 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:17,801 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:17,801 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:17,802 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:17,802 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:17,803 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:17,804 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:17,804 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:17,805 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:17,805 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:17,806 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:17,807 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-07-01 22:19:17,807 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-07-01 22:19:17,808 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-07-01 22:19:17,808 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-07-01 22:19:17,809 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-07-01 22:19:17,810 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-07-01 22:19:17,810 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-07-01 22:19:17,811 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-07-01 22:19:17,811 [DEBUG] lithops.job.job -- ExecutorID 51da88-0 | JobID M003 - Serializing function and data
# 2021-07-01 22:19:17,903 [DEBUG] lithops.job.serialize -- Referenced modules: /opt/conda/lib/python3.8/site-packages/shapely/geometry/polygon.py, /opt/conda/lib/python3.8/lib-dynload/math.cpython-38-x86_64-linux-gnu.so, /opt/conda/lib/python3.8/site-packages/lithops/storage/utils.py, /opt/conda/lib/python3.8/site-packages/shapely/geometry/multipoint.py, /opt/conda/lib/python3.8/io.py, /opt/conda/lib/python3.8/site-packages/numpy/__init__.py, /opt/conda/lib/python3.8/site-packages/shapely/geometry/geo.py, /opt/conda/lib/python3.8/site-packages/scipy/spatial/kdtree.py, /opt/conda/lib/python3.8/os.py, /opt/conda/lib/python3.8/site-packages/pandas/__init__.py, /opt/conda/lib/python3.8/site-packages/rasterio/windows.py, /opt/conda/lib/python3.8/site-packages/rasterio/__init__.py
# 2021-07-01 22:19:17,904 [DEBUG] lithops.job.serialize -- Modules to transmit: None
# 2021-07-01 22:19:17,905 [INFO] lithops.job.job -- ExecutorID 51da88-0 | JobID M003 - Uploading function and data - Total: 22.2KiB
# 2021-07-01 22:19:18,584 [DEBUG] lithops.storage.backends.ceph.ceph -- PUT Object lithops.jobs/51da88-0-M003/aggdata.pickle - Size: 18.7KiB - OK
# 2021-07-01 22:19:18,624 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M000 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:18,894 [DEBUG] lithops.storage.backends.ceph.ceph -- PUT Object lithops.jobs/51da88-0-M003/func.pickle - Size: 3.5KiB - OK
# 2021-07-01 22:19:18,895 [INFO] lithops.invokers -- ExecutorID 51da88-0 | JobID M003 - Starting function invocation: map_interpolation() - Total: 72 activations
# 2021-07-01 22:19:18,896 [DEBUG] lithops.invokers -- ExecutorID 51da88-0 | JobID M003 - Chunksize: 1 - Worker processes: 1
# 2021-07-01 22:19:18,896 [DEBUG] lithops.util.metrics -- Sending metric "job_total_calls 72" to http://77.231.202.2:30091/metrics/job/lithops/instance/51da88/job_id/51da88-0-M003/function_name/map_interpolation
# 2021-07-01 22:19:19,085 [DEBUG] lithops.serverless.backends.k8s.k8s -- ExecutorID 51da88-0 | JobID M003 - Going to run 72 activations in 72 workers
# 2021-07-01 22:19:19,141 [DEBUG] lithops.invokers -- ExecutorID 51da88-0 | JobID M003 - Job invoked (0.236s) - Activation ID: lithops-51da88-0-m003
# 2021-07-01 22:19:19,143 [INFO] lithops.invokers -- ExecutorID 51da88-0 | JobID M003 - View execution logs at /tmp/lithops/logs/51da88-0-M003.log
# 2021-07-01 22:19:19,147 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M003 - Starting Storage job monitor
# 2021-07-01 22:19:19,154 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M001 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:19,156 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M003 - Pending: 72 - Running: 0 - Done: 0

# %%
out_chunks = lith.get_result()
# Out:
# 2021-07-01 22:19:19,168 [INFO] lithops.wait -- ExecutorID 51da88-0 - Getting results from functions
# 2021-07-01 22:19:19,763 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M002 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:20,641 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M000 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:21,170 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M001 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:21,175 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M003 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:21,778 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M002 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:22,657 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M000 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:23,189 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M001 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:23,193 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M003 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:23,798 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M002 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:24,674 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M000 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:25,204 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M001 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:25,210 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M003 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:25,816 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M002 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:26,692 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M000 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:27,223 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M001 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:27,228 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M003 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:27,834 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M002 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:28,707 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M000 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:29,241 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M001 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:29,244 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M003 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:29,849 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M002 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:30,727 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M000 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:31,264 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M003 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:31,269 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M001 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:31,868 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M002 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:32,746 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M000 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:33,286 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M003 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:33,337 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M001 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:33,884 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M002 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:34,764 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M000 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:35,303 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M003 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:35,353 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M001 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:35,900 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M002 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:36,781 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M000 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:37,321 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M003 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:37,368 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M001 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:37,914 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M002 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:38,805 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M000 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:39,337 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M003 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:39,382 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M001 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:39,929 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M002 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:41,137 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M000 - Pending: 71 - Running: 1 - Done: 0
# 2021-07-01 22:19:41,563 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M003 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:41,568 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M001 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:42,618 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M002 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:43,155 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M000 - Pending: 68 - Running: 4 - Done: 0
# 2021-07-01 22:19:43,590 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M001 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:43,592 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M003 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:44,636 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M002 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:45,174 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M000 - Pending: 68 - Running: 4 - Done: 0
# 2021-07-01 22:19:45,607 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M001 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:45,612 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M003 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:46,654 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M002 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:47,192 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M000 - Pending: 68 - Running: 4 - Done: 0
# 2021-07-01 22:19:47,625 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M001 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:47,631 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M003 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:48,671 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M002 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:49,212 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M000 - Pending: 68 - Running: 4 - Done: 0
# 2021-07-01 22:19:49,640 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M001 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:49,644 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M003 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:50,689 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M002 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:51,557 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M000 - Pending: 66 - Running: 6 - Done: 0
# 2021-07-01 22:19:51,659 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M003 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:51,662 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M001 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:52,705 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M002 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:53,757 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M000 - Pending: 53 - Running: 19 - Done: 0
# 2021-07-01 22:19:53,792 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M003 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:53,798 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M001 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:54,730 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M002 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:55,792 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M000 - Pending: 50 - Running: 22 - Done: 0
# 2021-07-01 22:19:55,942 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M001 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:55,985 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M003 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:56,747 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M002 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:57,818 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M000 - Pending: 38 - Running: 34 - Done: 0
# 2021-07-01 22:19:57,958 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M001 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:58,040 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M003 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:58,763 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M002 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:19:59,845 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M000 - Pending: 37 - Running: 35 - Done: 0
# 2021-07-01 22:19:59,978 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M001 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:20:00,060 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M003 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:20:00,780 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M002 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:20:01,869 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M000 - Pending: 36 - Running: 36 - Done: 0
# 2021-07-01 22:20:01,995 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M001 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:20:02,074 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M003 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:20:02,795 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M002 - Pending: 72 - Running: 0 - Done: 0
# 2021-07-01 22:20
[DEBUG] lithops.future -- ExecutorID 51da88-0 | JobID M002 - Got status from call 00069 - Activation ID: 959fb3ab0dfb - Time: 15.13 seconds
# 2021-07-01 22:26:17,499 [DEBUG] lithops.future -- ExecutorID 51da88-0 | JobID M002 - Got status from call 00061 - Activation ID: 69f43941fb13 - Time: 21.39 seconds
# 2021-07-01 22:26:17,504 [DEBUG] lithops.future -- ExecutorID 51da88-0 | JobID M002 - Got status from call 00070 - Activation ID: 1c160e4c4163 - Time: 14.84 seconds
# 2021-07-01 22:26:17,512 [DEBUG] lithops.future -- ExecutorID 51da88-0 | JobID M002 - Got output from call 00066 - Activation ID: aba04d77e1cd
# 2021-07-01 22:26:17,515 [DEBUG] lithops.future -- ExecutorID 51da88-0 | JobID M002 - Got output from call 00065 - Activation ID: 9151acc0b9d7
# 2021-07-01 22:26:17,542 [DEBUG] lithops.future -- ExecutorID 51da88-0 | JobID M002 - Got output from call 00062 - Activation ID: 318edd785587
# 2021-07-01 22:26:17,553 [DEBUG] lithops.future -- ExecutorID 51da88-0 | JobID M002 - Got output from call 00067 - Activation ID: ab366dee0956
# 2021-07-01 22:26:17,569 [DEBUG] lithops.future -- ExecutorID 51da88-0 | JobID M002 - Got output from call 00068 - Activation ID: 1f71d584e40f
# 2021-07-01 22:26:17,574 [DEBUG] lithops.future -- ExecutorID 51da88-0 | JobID M002 - Got output from call 00063 - Activation ID: 04da03136c93
# 2021-07-01 22:26:17,577 [DEBUG] lithops.future -- ExecutorID 51da88-0 | JobID M002 - Got output from call 00070 - Activation ID: 1c160e4c4163
# 2021-07-01 22:26:17,593 [DEBUG] lithops.future -- ExecutorID 51da88-0 | JobID M002 - Got output from call 00069 - Activation ID: 959fb3ab0dfb
# 2021-07-01 22:26:17,605 [DEBUG] lithops.future -- ExecutorID 51da88-0 | JobID M002 - Got output from call 00061 - Activation ID: 69f43941fb13
# 2021-07-01 22:26:18,037 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M002 - Pending: 0 - Running: 0 - Done: 72
# 2021-07-01 22:26:18,039 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M002 - Storage job monitor finished
# 2021-07-01 22:26:18,435 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M000 - Pending: 0 - Running: 2 - Done: 70
# 2021-07-01 22:26:18,615 [DEBUG] lithops.future -- ExecutorID 51da88-0 | JobID M002 - Got status from call 00071 - Activation ID: 9a4d9039a499 - Time: 15.23 seconds
# 2021-07-01 22:26:18,628 [DEBUG] lithops.future -- ExecutorID 51da88-0 | JobID M002 - Got output from call 00071 - Activation ID: 9a4d9039a499
# 2021-07-01 22:26:20,524 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M000 - Pending: 0 - Running: 2 - Done: 70
# 2021-07-01 22:26:22,620 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M000 - Pending: 0 - Running: 2 - Done: 70
# 2021-07-01 22:26:24,723 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M000 - Pending: 0 - Running: 1 - Done: 71
# 2021-07-01 22:26:25,313 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M000 - Pending: 0 - Running: 1 - Done: 71
# 2021-07-01 22:26:25,651 [DEBUG] lithops.future -- ExecutorID 51da88-0 | JobID M000 - Got status from call 00060 - Activation ID: 935c075e1c2c - Time: 309.02 seconds
# 2021-07-01 22:26:25,667 [DEBUG] lithops.future -- ExecutorID 51da88-0 | JobID M000 - Got output from call 00060 - Activation ID: 935c075e1c2c
# 2021-07-01 22:26:27,403 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M000 - Pending: 0 - Running: 1 - Done: 71
# 2021-07-01 22:26:29,503 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M000 - Pending: 0 - Running: 0 - Done: 72
# 2021-07-01 22:26:29,505 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M000 - Storage job monitor finished
# 2021-07-01 22:26:29,683 [DEBUG] lithops.future -- ExecutorID 51da88-0 | JobID M000 - Got status from call 00064 - Activation ID: 93958fa20880 - Time: 288.42 seconds
# 2021-07-01 22:26:29,695 [DEBUG] lithops.future -- ExecutorID 51da88-0 | JobID M000 - Got output from call 00064 - Activation ID: 93958fa20880
# 2021-07-01 22:26:30,702 [DEBUG] lithops.serverless.backends.k8s.k8s -- Deleting job lithops-51da88-0-m002
# 2021-07-01 22:26:30,716 [DEBUG] lithops.serverless.backends.k8s.k8s -- Deleting job lithops-51da88-0-m000
# 2021-07-01 22:26:30,747 [DEBUG] lithops.serverless.backends.k8s.k8s -- Deleting job lithops-51da88-0-m001
# 2021-07-01 22:26:30,920 [DEBUG] lithops.serverless.backends.k8s.k8s -- Deleting job lithops-51da88-0-m003
# 2021-07-01 22:26:30,955 [INFO] lithops.executors -- ExecutorID 51da88-0 - Cleaning temporary data
# 2021-07-01 22:26:30,976 [DEBUG] lithops.executors -- ExecutorID 51da88-0 Finished getting results

# %% [markdown]
# Join split subsets into a tile:

# %%
def gather_blocks(tile, splits, data_field, storage):

    from rasterio.windows import Window
    
    # Get width and height from original tile
    with rasterio.open(storage.get_object(bucket=BUCKET, key=f'MDT/{tile}.tif', stream=True)) as og:
        height = og.profile['height']
        width = og.profile['width']
    
    chunk_tiles = storage.list_keys(bucket=BUCKET, prefix=f'tmp/{data_field}/{tile}/chunk')
        
    # Open first object to obtain profile metadata
    with rasterio.open(storage.get_object(bucket=BUCKET, key=chunk_tiles[0], stream=True)) as src:
        profile = src.profile
        profile.update(width=width)
        profile.update(height=height)

    # Iterate each object and print its block into the destination file
    with rasterio.open("output", "w", **profile) as dest: 
        for chunk in chunk_tiles:
            j, i = os.path.splitext(os.path.basename(chunk))[0].rsplit('_')[1].split('-')
            j, i = int(j), int(i)
            with rasterio.open(storage.get_object(bucket=BUCKET, key=chunk, stream=True)) as src:
                step_w = math.floor(width / splits)
                step_h = math.floor(height / splits)
                curr_window = Window(round(step_w * i), round(step_h * j), src.width, src.height)
                content = src.read(1)
                dest.write(content, 1, window=curr_window)
            # storage.delete_object(bucket=BUCKET, key=chunk)
    
    output_key = os.path.join('tmp', data_field, tile, '_'.join([tile, data_field.upper()+'.tif']))
    with open('output', 'rb') as out_file:
        storage.put_object(bucket=BUCKET, key=output_key, body=out_file)  
    
    return output_key

# %% [markdown]
# Combine previous split subsets:

# %%
lith.map(gather_blocks, tiles, extra_args=(SPLITS, 'extrad'), runtime_memory=2048)
# Out:
# 2021-07-01 22:26:52,879 [INFO] lithops.invokers -- ExecutorID 51da88-0 | JobID M004 - Selected Runtime: jsampe/lithops-k8s-geospatial - 2048MB
# 2021-07-01 22:26:52,882 [DEBUG] lithops.storage.storage -- Runtime metadata found in local cache
# 2021-07-01 22:26:52,885 [DEBUG] lithops.job.job -- ExecutorID 51da88-0 | JobID M004 - Serializing function and data
# 2021-07-01 22:26:52,898 [DEBUG] lithops.job.serialize -- Referenced modules: /opt/conda/lib/python3.8/lib-dynload/math.cpython-38-x86_64-linux-gnu.so, /opt/conda/lib/python3.8/os.py, /opt/conda/lib/python3.8/site-packages/rasterio/windows.py, /opt/conda/lib/python3.8/site-packages/rasterio/__init__.py
# 2021-07-01 22:26:52,899 [DEBUG] lithops.job.serialize -- Modules to transmit: None
# 2021-07-01 22:26:52,900 [INFO] lithops.job.job -- ExecutorID 51da88-0 | JobID M004 - Uploading function and data - Total: 2.3KiB
# 2021-07-01 22:26:53,100 [DEBUG] lithops.storage.backends.ceph.ceph -- PUT Object lithops.jobs/51da88-0-M004/aggdata.pickle - Size: 720.0B - OK
# 2021-07-01 22:26:53,430 [DEBUG] lithops.storage.backends.ceph.ceph -- PUT Object lithops.jobs/51da88-0-M004/func.pickle - Size: 1.6KiB - OK
# 2021-07-01 22:26:53,433 [INFO] lithops.invokers -- ExecutorID 51da88-0 | JobID M004 - Starting function invocation: gather_blocks() - Total: 8 activations
# 2021-07-01 22:26:53,435 [DEBUG] lithops.invokers -- ExecutorID 51da88-0 | JobID M004 - Chunksize: 1 - Worker processes: 1
# 2021-07-01 22:26:53,436 [DEBUG] lithops.util.metrics -- Sending metric "job_total_calls 8" to http://77.231.202.2:30091/metrics/job/lithops/instance/51da88/job_id/51da88-0-M004/function_name/gather_blocks
# 2021-07-01 22:26:53,640 [DEBUG] lithops.serverless.backends.k8s.k8s -- Starting Lithops master Pod
# 2021-07-01 22:27:15,118 [DEBUG] lithops.serverless.backends.k8s.k8s -- ExecutorID 51da88-0 | JobID M004 - Going to run 8 activations in 8 workers
# 2021-07-01 22:27:15,179 [DEBUG] lithops.invokers -- ExecutorID 51da88-0 | JobID M004 - Job invoked (21.729s) - Activation ID: lithops-51da88-0-m004
# 2021-07-01 22:27:15,180 [INFO] lithops.invokers -- ExecutorID 51da88-0 | JobID M004 - View execution logs at /tmp/lithops/logs/51da88-0-M004.log
# 2021-07-01 22:27:15,182 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M004 - Starting Storage job monitor
# [<lithops.future.ResponseFuture at 0x7fc5a560f0d0>,
#  <lithops.future.ResponseFuture at 0x7fc5a4647610>,
#  <lithops.future.ResponseFuture at 0x7fc5a4647820>,
#  <lithops.future.ResponseFuture at 0x7fc5a45a4850>,
#  <lithops.future.ResponseFuture at 0x7fc5a45a4ca0>,
#  <lithops.future.ResponseFuture at 0x7fc5a45a4cd0>,
#  <lithops.future.ResponseFuture at 0x7fc5a3573100>,
#  <lithops.future.ResponseFuture at 0x7fc5a3573580>]

# %%
lith.map(gather_blocks, tiles, extra_args=(SPLITS, 'humi'), runtime_memory=2048)
# Out:
# 2021-07-01 22:27:15,202 [INFO] lithops.invokers -- ExecutorID 51da88-0 | JobID M005 - Selected Runtime: jsampe/lithops-k8s-geospatial - 2048MB
# 2021-07-01 22:27:15,227 [DEBUG] lithops.storage.storage -- Runtime metadata found in local cache
# 2021-07-01 22:27:15,257 [DEBUG] lithops.job.job -- ExecutorID 51da88-0 | JobID M005 - Serializing function and data
# 2021-07-01 22:27:15,265 [DEBUG] lithops.job.serialize -- Referenced modules: /opt/conda/lib/python3.8/lib-dynload/math.cpython-38-x86_64-linux-gnu.so, /opt/conda/lib/python3.8/os.py, /opt/conda/lib/python3.8/site-packages/rasterio/windows.py, /opt/conda/lib/python3.8/site-packages/rasterio/__init__.py
# 2021-07-01 22:27:15,268 [DEBUG] lithops.job.serialize -- Modules to transmit: None
# 2021-07-01 22:27:15,269 [INFO] lithops.job.job -- ExecutorID 51da88-0 | JobID M005 - Uploading function and data - Total: 2.3KiB
# 2021-07-01 22:27:15,299 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M004 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:15,582 [DEBUG] lithops.storage.backends.ceph.ceph -- PUT Object lithops.jobs/51da88-0-M005/aggdata.pickle - Size: 704.0B - OK
# 2021-07-01 22:27:15,883 [DEBUG] lithops.storage.backends.ceph.ceph -- PUT Object lithops.jobs/51da88-0-M005/func.pickle - Size: 1.6KiB - OK
# 2021-07-01 22:27:15,884 [INFO] lithops.invokers -- ExecutorID 51da88-0 | JobID M005 - Starting function invocation: gather_blocks() - Total: 8 activations
# 2021-07-01 22:27:15,885 [DEBUG] lithops.invokers -- ExecutorID 51da88-0 | JobID M005 - Chunksize: 1 - Worker processes: 1
# 2021-07-01 22:27:15,886 [DEBUG] lithops.util.metrics -- Sending metric "job_total_calls 8" to http://77.231.202.2:30091/metrics/job/lithops/instance/51da88/job_id/51da88-0-M005/function_name/gather_blocks
# 2021-07-01 22:27:15,980 [DEBUG] lithops.serverless.backends.k8s.k8s -- ExecutorID 51da88-0 | JobID M005 - Going to run 8 activations in 8 workers
# 2021-07-01 22:27:16,074 [DEBUG] lithops.invokers -- ExecutorID 51da88-0 | JobID M005 - Job invoked (0.177s) - Activation ID: lithops-51da88-0-m005
# 2021-07-01 22:27:16,076 [INFO] lithops.invokers -- ExecutorID 51da88-0 | JobID M005 - View execution logs at /tmp/lithops/logs/51da88-0-M005.log
# 2021-07-01 22:27:16,077 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M005 - Starting Storage job monitor
# [<lithops.future.ResponseFuture at 0x7fc5a4586a00>,
#  <lithops.future.ResponseFuture at 0x7fc5a35737f0>,
#  <lithops.future.ResponseFuture at 0x7fc5a3573220>,
#  <lithops.future.ResponseFuture at 0x7fc5a3573730>,
#  <lithops.future.ResponseFuture at 0x7fc5a3573ee0>,
#  <lithops.future.ResponseFuture at 0x7fc5a35733d0>,
#  <lithops.future.ResponseFuture at 0x7fc5a3573850>,
#  <lithops.future.ResponseFuture at 0x7fc5a35739a0>]

# %%
lith.map(gather_blocks, tiles, extra_args=(SPLITS, 'rad'), runtime_memory=2048)
# Out:
# 2021-07-01 22:27:16,101 [INFO] lithops.invokers -- ExecutorID 51da88-0 | JobID M006 - Selected Runtime: jsampe/lithops-k8s-geospatial - 2048MB
# 2021-07-01 22:27:16,103 [DEBUG] lithops.storage.storage -- Runtime metadata found in local cache
# 2021-07-01 22:27:16,105 [DEBUG] lithops.job.job -- ExecutorID 51da88-0 | JobID M006 - Serializing function and data
# 2021-07-01 22:27:16,113 [DEBUG] lithops.job.serialize -- Referenced modules: /opt/conda/lib/python3.8/lib-dynload/math.cpython-38-x86_64-linux-gnu.so, /opt/conda/lib/python3.8/os.py, /opt/conda/lib/python3.8/site-packages/rasterio/windows.py, /opt/conda/lib/python3.8/site-packages/rasterio/__init__.py
# 2021-07-01 22:27:16,114 [DEBUG] lithops.job.serialize -- Modules to transmit: None
# 2021-07-01 22:27:16,116 [INFO] lithops.job.job -- ExecutorID 51da88-0 | JobID M006 - Uploading function and data - Total: 2.3KiB
# 2021-07-01 22:27:16,208 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M005 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:16,991 [DEBUG] lithops.storage.backends.ceph.ceph -- PUT Object lithops.jobs/51da88-0-M006/aggdata.pickle - Size: 696.0B - OK
# 2021-07-01 22:27:17,418 [DEBUG] lithops.storage.backends.ceph.ceph -- PUT Object lithops.jobs/51da88-0-M006/func.pickle - Size: 1.6KiB - OK
# 2021-07-01 22:27:17,420 [INFO] lithops.invokers -- ExecutorID 51da88-0 | JobID M006 - Starting function invocation: gather_blocks() - Total: 8 activations
# 2021-07-01 22:27:17,445 [DEBUG] lithops.invokers -- ExecutorID 51da88-0 | JobID M006 - Chunksize: 1 - Worker processes: 1
# 2021-07-01 22:27:17,447 [DEBUG] lithops.util.metrics -- Sending metric "job_total_calls 8" to http://77.231.202.2:30091/metrics/job/lithops/instance/51da88/job_id/51da88-0-M006/function_name/gather_blocks
# 2021-07-01 22:27:17,533 [DEBUG] lithops.serverless.backends.k8s.k8s -- ExecutorID 51da88-0 | JobID M006 - Going to run 8 activations in 8 workers
# 2021-07-01 22:27:17,537 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M004 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:17,570 [DEBUG] lithops.invokers -- ExecutorID 51da88-0 | JobID M006 - Job invoked (0.083s) - Activation ID: lithops-51da88-0-m006
# 2021-07-01 22:27:17,571 [INFO] lithops.invokers -- ExecutorID 51da88-0 | JobID M006 - View execution logs at /tmp/lithops/logs/51da88-0-M006.log
# 2021-07-01 22:27:17,572 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M006 - Starting Storage job monitor
# [<lithops.future.ResponseFuture at 0x7fc5a46b6d30>,
#  <lithops.future.ResponseFuture at 0x7fc5a4581a00>,
#  <lithops.future.ResponseFuture at 0x7fc5a45a4640>,
#  <lithops.future.ResponseFuture at 0x7fc5a45a4df0>,
#  <lithops.future.ResponseFuture at 0x7fc5a45a4eb0>,
#  <lithops.future.ResponseFuture at 0x7fc5a45a4be0>,
#  <lithops.future.ResponseFuture at 0x7fc5a45a4d60>,
#  <lithops.future.ResponseFuture at 0x7fc5a45a47c0>]

# %%
lith.map(gather_blocks, tiles, extra_args=(SPLITS, 'temp'), runtime_memory=2048)
# Out:
# 2021-07-01 22:27:17,599 [INFO] lithops.invokers -- ExecutorID 51da88-0 | JobID M007 - Selected Runtime: jsampe/lithops-k8s-geospatial - 2048MB
# 2021-07-01 22:27:17,602 [DEBUG] lithops.storage.storage -- Runtime metadata found in local cache
# 2021-07-01 22:27:17,605 [DEBUG] lithops.job.job -- ExecutorID 51da88-0 | JobID M007 - Serializing function and data
# 2021-07-01 22:27:17,613 [DEBUG] lithops.job.serialize -- Referenced modules: /opt/conda/lib/python3.8/lib-dynload/math.cpython-38-x86_64-linux-gnu.so, /opt/conda/lib/python3.8/os.py, /opt/conda/lib/python3.8/site-packages/rasterio/windows.py, /opt/conda/lib/python3.8/site-packages/rasterio/__init__.py
# 2021-07-01 22:27:17,614 [DEBUG] lithops.job.serialize -- Modules to transmit: None
# 2021-07-01 22:27:17,615 [INFO] lithops.job.job -- ExecutorID 51da88-0 | JobID M007 - Uploading function and data - Total: 2.3KiB
# 2021-07-01 22:27:17,723 [DEBUG] lithops.storage.backends.ceph.ceph -- PUT Object lithops.jobs/51da88-0-M007/aggdata.pickle - Size: 704.0B - OK
# 2021-07-01 22:27:17,724 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M006 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:18,330 [DEBUG] lithops.storage.backends.ceph.ceph -- PUT Object lithops.jobs/51da88-0-M007/func.pickle - Size: 1.6KiB - OK
# 2021-07-01 22:27:18,350 [INFO] lithops.invokers -- ExecutorID 51da88-0 | JobID M007 - Starting function invocation: gather_blocks() - Total: 8 activations
# 2021-07-01 22:27:18,358 [DEBUG] lithops.invokers -- ExecutorID 51da88-0 | JobID M007 - Chunksize: 1 - Worker processes: 1
# 2021-07-01 22:27:18,362 [DEBUG] lithops.util.metrics -- Sending metric "job_total_calls 8" to http://77.231.202.2:30091/metrics/job/lithops/instance/51da88/job_id/51da88-0-M007/function_name/gather_blocks
# 2021-07-01 22:27:18,388 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M005 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:18,452 [DEBUG] lithops.serverless.backends.k8s.k8s -- ExecutorID 51da88-0 | JobID M007 - Going to run 8 activations in 8 workers
# 2021-07-01 22:27:18,520 [DEBUG] lithops.invokers -- ExecutorID 51da88-0 | JobID M007 - Job invoked (0.135s) - Activation ID: lithops-51da88-0-m007
# 2021-07-01 22:27:18,521 [INFO] lithops.invokers -- ExecutorID 51da88-0 | JobID M007 - View execution logs at /tmp/lithops/logs/51da88-0-M007.log
# 2021-07-01 22:27:18,523 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M007 - Starting Storage job monitor
# [<lithops.future.ResponseFuture at 0x7fc5a465c880>,
#  <lithops.future.ResponseFuture at 0x7fc5a452ebe0>,
#  <lithops.future.ResponseFuture at 0x7fc5a452e250>,
#  <lithops.future.ResponseFuture at 0x7fc5a452e610>,
#  <lithops.future.ResponseFuture at 0x7fc5a452e700>,
#  <lithops.future.ResponseFuture at 0x7fc5a452e280>,
#  <lithops.future.ResponseFuture at 0x7fc5a452e3a0>,
#  <lithops.future.ResponseFuture at 0x7fc5a452eb50>]

# %%
fut = lith.map(gather_blocks, tiles, extra_args=(SPLITS, 'wind'), runtime_memory=2048)
# Out:
# 2021-07-01 22:27:18,545 [INFO] lithops.invokers -- ExecutorID 51da88-0 | JobID M008 - Selected Runtime: jsampe/lithops-k8s-geospatial - 2048MB
# 2021-07-01 22:27:18,547 [DEBUG] lithops.storage.storage -- Runtime metadata found in local cache
# 2021-07-01 22:27:18,550 [DEBUG] lithops.job.job -- ExecutorID 51da88-0 | JobID M008 - Serializing function and data
# 2021-07-01 22:27:18,557 [DEBUG] lithops.job.serialize -- Referenced modules: /opt/conda/lib/python3.8/lib-dynload/math.cpython-38-x86_64-linux-gnu.so, /opt/conda/lib/python3.8/os.py, /opt/conda/lib/python3.8/site-packages/rasterio/windows.py, /opt/conda/lib/python3.8/site-packages/rasterio/__init__.py
# 2021-07-01 22:27:18,558 [DEBUG] lithops.job.serialize -- Modules to transmit: None
# 2021-07-01 22:27:18,559 [INFO] lithops.job.job -- ExecutorID 51da88-0 | JobID M008 - Uploading function and data - Total: 2.3KiB
# 2021-07-01 22:27:18,671 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M007 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:18,776 [DEBUG] lithops.storage.backends.ceph.ceph -- PUT Object lithops.jobs/51da88-0-M008/aggdata.pickle - Size: 704.0B - OK
# 2021-07-01 22:27:18,977 [DEBUG] lithops.storage.backends.ceph.ceph -- PUT Object lithops.jobs/51da88-0-M008/func.pickle - Size: 1.6KiB - OK
# 2021-07-01 22:27:18,979 [INFO] lithops.invokers -- ExecutorID 51da88-0 | JobID M008 - Starting function invocation: gather_blocks() - Total: 8 activations
# 2021-07-01 22:27:18,980 [DEBUG] lithops.invokers -- ExecutorID 51da88-0 | JobID M008 - Chunksize: 1 - Worker processes: 1
# 2021-07-01 22:27:18,982 [DEBUG] lithops.util.metrics -- Sending metric "job_total_calls 8" to http://77.231.202.2:30091/metrics/job/lithops/instance/51da88/job_id/51da88-0-M008/function_name/gather_blocks
# 2021-07-01 22:27:19,087 [DEBUG] lithops.serverless.backends.k8s.k8s -- ExecutorID 51da88-0 | JobID M008 - Going to run 8 activations in 8 workers
# 2021-07-01 22:27:19,106 [DEBUG] lithops.invokers -- ExecutorID 51da88-0 | JobID M008 - Job invoked (0.109s) - Activation ID: lithops-51da88-0-m008
# 2021-07-01 22:27:19,107 [INFO] lithops.invokers -- ExecutorID 51da88-0 | JobID M008 - View execution logs at /tmp/lithops/logs/51da88-0-M008.log
# 2021-07-01 22:27:19,110 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M008 - Starting Storage job monitor

# %%
out_combined = lith.get_result()
# Out:
# 2021-07-01 22:27:19,128 [INFO] lithops.wait -- ExecutorID 51da88-0 - Getting results from functions
# 2021-07-01 22:27:19,324 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M008 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:19,703 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M004 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:20,107 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M006 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:20,716 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M005 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:20,823 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M007 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:21,436 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M008 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:21,819 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M004 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:22,208 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M006 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:22,814 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M005 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:22,955 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M007 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:23,528 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M008 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:23,908 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M004 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:24,320 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M006 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:24,903 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M005 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:25,064 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M007 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:25,632 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M008 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:26,016 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M004 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:26,411 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M006 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:27,000 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M005 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:27,171 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M007 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:27,729 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M008 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:28,124 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M004 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:28,520 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M006 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:29,095 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M005 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:29,560 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M007 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:29,840 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M008 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:30,379 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M004 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:30,691 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M006 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:31,211 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M005 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:31,652 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M007 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:32,195 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M008 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:32,471 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M004 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:32,884 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M006 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:33,556 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M005 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:33,824 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M007 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:34,304 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M008 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:34,611 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M004 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:35,144 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M006 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:35,748 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M005 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:36,129 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M007 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:36,451 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M008 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:36,720 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M004 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:37,316 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M006 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:37,936 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M005 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:38,228 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M007 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:38,603 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M008 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:39,012 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M004 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:39,427 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M006 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:40,032 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M005 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:40,696 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M007 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:40,768 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M008 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:41,343 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M004 - Pending: 6 - Running: 2 - Done: 0
# 2021-07-01 22:27:41,652 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M006 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:42,400 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M005 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:43,160 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M007 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:43,194 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M008 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:43,632 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M004 - Pending: 3 - Running: 5 - Done: 0
# 2021-07-01 22:27:43,892 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M006 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:44,785 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M005 - Pending: 7 - Running: 1 - Done: 0
# 2021-07-01 22:27:45,643 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M008 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:45,659 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M007 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:46,219 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M004 - Pending: 2 - Running: 6 - Done: 0
# 2021-07-01 22:27:47,171 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M006 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:49,439 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M005 - Pending: 6 - Running: 2 - Done: 0
# 2021-07-01 22:27:50,084 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M008 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:50,130 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M007 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:27:51,724 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M004 - Pending: 0 - Running: 7 - Done: 1
# 2021-07-01 22:27:52,252 [DEBUG] lithops.future -- ExecutorID 51da88-0 | JobID M004 - Got status from call 00000 - Activation ID: 844891010562 - Time: 5.72 seconds
# 2021-07-01 22:27:53,199 [DEBUG] lithops.future -- ExecutorID 51da88-0 | JobID M004 - Got output from call 00000 - Activation ID: 844891010562
# 2021-07-01 22:27:54,133 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M006 - Pending: 5 - Running: 3 - Done: 0
# 2021-07-01 22:28:23,059 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M007 - Pending: 2 - Running: 6 - Done: 0
# 2021-07-01 22:28:23,077 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M004 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22
    T4 = 4.903 * np.power((273.3 + temperatures),4)/1000000000
    rSrS0 = global_radiations/(external_radiations * 0.75)
    rN = 0.8* global_radiations-T4*(0.34-0.14*np.sqrt(eA))*((1.35*rSrS0)-0.35)
    den = delta + gamma *(1 + 0.34* wind_speeds)
    tRad = 0.408 * delta * rN / den
    tAdv = gamma * (900/(temperatures+273))*wind_speeds * (eSat - eA)/den
    return ((tRad + tAdv) * 7 * KCs).astype('float32')

# %%
vineyard = ['VI', 'VO', 'VF', 'FV', 'CV' ]
olive_grove = ['OV', 'VO', 'OF', 'FL', 'OC']
fruit = ['FY', 'VF', 'OF', 'FF', 'CF']
nuts = ['FS', 'FV', 'FL', 'FF', 'CS' ]
citrus = ['CI', 'CV', 'OC', 'CF', 'CS' ]

def get_kc(feature):
    
    # TODO: Get more precise values of Kc
    sigpac_use = feature['properties']['uso_sigpac']
    if sigpac_use in vineyard:
        # Grapes for wine - 0.3, 0.7, 0.45
        return 0.7  
    if sigpac_use in olive_grove:
        # Olive grove - ini: 0.65, med: 0.7, end: 0.7
        return 0.7 
    if sigpac_use in fruit:
        # Apples, Cherries, Pears - 0.45, 0.95, 0.7
        return 0.95
    if sigpac_use in nuts:
        # Almonds - 0.4, 0.9, 0.65
        return 0.9
    if sigpac_use in citrus:
        # Citrus, without ground coverage - 0.7, 0.65, 0.7
        return 0.65
    
    return None

# %%
def get_geometry_window(src, geom_bounds):
    left, bottom, right, top = geom_bounds
    src_left, src_bottom, src_right, src_top = src.bounds
    window = src.window(max(left,src_left), max(bottom,src_bottom), min(right,src_right), min(top,src_top))
    window_floored = window.round_offsets(op='floor', pixel_precision=3)
    w = math.ceil(window.width + window.col_off - window_floored.col_off)
    h = math.ceil(window.height + window.row_off - window_floored.row_off)
    return Window(window_floored.col_off, window_floored.row_off, w, h)

# %%
def compute_evapotranspiration_by_shape(tem, hum, win, rad, extrad, dst):
    
    import fiona
    from shapely.geometry import shape, box
    from rasterio import features
    
    non_arable_land = ['AG', 'CA', 'ED', 'FO', 'IM', 'PA', 'PR', 'ZU', 'ZV']
    
    with fiona.open('zip://shape.zip') as shape_src:
        for feature in shape_src.filter(bbox=tem.bounds):
            KC = get_kc(feature) 
            if KC is not None:   
                geom = shape(feature['geometry'])  
                window = get_geometry_window(tem, geom.bounds)              
                win_transform = rasterio.windows.transform(window, tem.transform)
                # Convert shape to raster matrix
                image = features.rasterize([geom],
                                           out_shape=(window.height, window.width),
                                           transform = win_transform,
                                           fill = 0,
                                           default_value = 1).astype('bool')
                # Get values to compute evapotranspiration
                temperatures = tem.read(1, window=window)
                humidities = hum.read(1, window=window)
                wind_speeds = win.read(1, window=window)
                # Convert from W to MJ (0.0036)
                global_radiations = rad.read(1, window=window) * 0.0036
                external_radiations = extrad.read(1, window=window) * 0.0036
                KCs = np.full(temperatures.shape, KC)
                # TODO: compute external radiation
                #external_radiations = np.full(temperatures.shape, 14)
                # TODO: compute global radiation
                # global_radiations = np.full(temperatures.shape, 10)
                etc = compute_crop_evapotranspiration(
                        temperatures,
                        humidities,
                        wind_speeds,
                        external_radiations,
                        global_radiations,
                        KCs
                )
                etc[temperatures == tem.nodata] = dst.nodata
                etc[np.logical_not(image)] = dst.nodata
                dst.write(etc + dst.read(1, window=window), 1, window=window)

# %%
def compute_global_evapotranspiration(tem, hum, win, rad, extrad, dst):    
    for ji, window in tem.block_windows(1):
        bounds = rasterio.windows.bounds(window, tem.transform)
        temperatures = tem.read(1, window=window)
        humidities = hum.read(1, window=window)
        wind_speeds = win.read(1, window=window)
         # Convert from W to MJ (0.0036)
        global_radiations = rad.read(1, window=window) * 0.0036
        external_radiations = extrad.read(1, window=window) * 0.0036
        # TODO: compute external radiation
        #external_radiations = np.full(temperatures.shape, 14)
        # TODO: compute global radiation
        # global_radiations = np.full(temperatures.shape, 10)
        # TODO: compute KCs
        KCs = np.full(temperatures.shape, 1)
        etc = compute_crop_evapotranspiration(
                temperatures,
                humidities,
                wind_speeds,
                external_radiations,
                global_radiations,
                KCs
        )
        dst.write(np.where(temperatures == tem.nodata, dst.nodata, etc), 1, window=window)

# %%
def combine_calculations(tile, storage):
    
    from functools import partial
      
    # Download shapefile
    shapefile = storage.get_object(bucket=BUCKET, key='shapefile.zip', stream=True)
    with open('shape.zip', 'wb') as shapf:
        for chunk in iter(partial(shapefile.read, 200 * 1024 * 1024), ''):
            if not chunk:
                break
            shapf.write(chunk)
    
    temp = storage.get_object(bucket=BUCKET, key=f'tmp/temp/{tile}/{tile}_TEMP.tif', stream=True)
    humi = storage.get_object(bucket=BUCKET, key=f'tmp/humi/{tile}/{tile}_HUMI.tif', stream=True)
    rad = storage.get_object(bucket=BUCKET, key=f'tmp/rad/{tile}/{tile}_RAD.tif', stream=True)
    extrad = storage.get_object(bucket=BUCKET, key=f'tmp/extrad/{tile}/{tile}_EXTRAD.tif', stream=True)
    wind = storage.get_object(bucket=BUCKET, key=f'tmp/wind/{tile}/{tile}_WIND.tif', stream=True)
    
    with rasterio.open(temp) as temp_raster:
        with rasterio.open(humi) as humi_raster:
            with rasterio.open(rad) as rad_raster:
                with rasterio.open(extrad) as extrad_raster:
                    with rasterio.open(wind) as wind_raster:
                        profile = temp_raster.profile
                        profile.update(nodata=0)
        
                        with rasterio.open('output', 'w+', **profile) as dst:
#                             compute_global_evapotranspiration(temp_raster, humi_raster, wind_raster,
#                                                               rad_raster, extrad_raster, dst)
                            compute_evapotranspiration_by_shape(temp_raster, humi_raster, wind_raster,
                                                                rad_raster, extrad_raster, dst)
    
    out_key = f'etc/{tile}_ETC.tif'
    with open('output', 'rb') as output_f:
        storage.put_object(bucket=BUCKET, key=out_key, body=output_f)
    return out_key

# %%
fut = lith.map(combine_calculations, tiles, runtime_memory=2048)
# Out:
# 2021-07-01 22:29:44,911 [INFO] lithops.invokers -- ExecutorID 51da88-0 | JobID M009 - Selected Runtime: jsampe/lithops-k8s-geospatial - 2048MB
# 2021-07-01 22:29:44,914 [DEBUG] lithops.storage.storage -- Runtime metadata found in local cache
# 2021-07-01 22:29:44,918 [DEBUG] lithops.job.job -- ExecutorID 51da88-0 | JobID M009 - Serializing function and data
# 2021-07-01 22:29:44,967 [DEBUG] lithops.job.serialize -- Referenced modules: /opt/conda/lib/python3.8/site-packages/shapely/geometry/polygon.py, /opt/conda/lib/python3.8/lib-dynload/math.cpython-38-x86_64-linux-gnu.so, /opt/conda/lib/python3.8/site-packages/fiona/__init__.py, /opt/conda/lib/python3.8/site-packages/numpy/__init__.py, /opt/conda/lib/python3.8/site-packages/shapely/geometry/geo.py, /opt/conda/lib/python3.8/site-packages/shapely/geometry/__init__.py, /opt/conda/lib/python3.8/site-packages/shapely/__init__.py, /opt/conda/lib/python3.8/site-packages/rasterio/windows.py, /opt/conda/lib/python3.8/site-packages/rasterio/__init__.py, /opt/conda/lib/python3.8/functools.py
# 2021-07-01 22:29:44,968 [DEBUG] lithops.job.serialize -- Modules to transmit: None
# 2021-07-01 22:29:44,969 [INFO] lithops.job.job -- ExecutorID 51da88-0 | JobID M009 - Uploading function and data - Total: 5.1KiB
# 2021-07-01 22:29:45,163 [DEBUG] lithops.storage.backends.ceph.ceph -- PUT Object lithops.jobs/51da88-0-M009/aggdata.pickle - Size: 448.0B - OK
# 2021-07-01 22:29:45,318 [DEBUG] lithops.storage.backends.ceph.ceph -- PUT Object lithops.jobs/51da88-0-M009/func.pickle - Size: 4.6KiB - OK
# 2021-07-01 22:29:45,320 [INFO] lithops.invokers -- ExecutorID 51da88-0 | JobID M009 - Starting function invocation: combine_calculations() - Total: 8 activations
# 2021-07-01 22:29:45,323 [DEBUG] lithops.invokers -- ExecutorID 51da88-0 | JobID M009 - Chunksize: 1 - Worker processes: 1
# 2021-07-01 22:29:45,324 [DEBUG] lithops.util.metrics -- Sending metric "job_total_calls 8" to http://77.231.202.2:30091/metrics/job/lithops/instance/51da88/job_id/51da88-0-M009/function_name/combine_calculations
# 2021-07-01 22:29:45,426 [DEBUG] lithops.serverless.backends.k8s.k8s -- ExecutorID 51da88-0 | JobID M009 - Going to run 8 activations in 8 workers
# 2021-07-01 22:29:45,454 [DEBUG] lithops.invokers -- ExecutorID 51da88-0 | JobID M009 - Job invoked (0.109s) - Activation ID: lithops-51da88-0-m009
# 2021-07-01 22:29:45,455 [INFO] lithops.invokers -- ExecutorID 51da88-0 | JobID M009 - View execution logs at /tmp/lithops/logs/51da88-0-M009.log
# 2021-07-01 22:29:45,457 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Starting Storage job monitor

# %%
res = lith.get_result()
# Out:
# 2021-07-01 22:29:45,478 [INFO] lithops.wait -- ExecutorID 51da88-0 - Getting results from functions
# 2021-07-01 22:29:45,656 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:29:47,864 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:29:49,968 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:29:52,060 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 8 - Running: 0 - Done: 0
# 2021-07-01 22:29:54,163 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 7 - Running: 1 - Done: 0
# 2021-07-01 22:29:56,407 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 4 - Running: 4 - Done: 0
# 2021-07-01 22:29:58,512 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:30:01,787 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:30:04,117 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:30:06,222 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:30:08,348 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:30:10,456 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:30:12,579 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:30:14,840 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:30:16,950 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:30:19,064 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:30:21,227 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:30:23,324 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:30:25,579 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:30:27,748 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:30:29,924 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:30:32,051 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:30:34,155 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:30:36,268 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:30:38,375 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:30:40,476 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:30:42,581 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:30:44,687 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:30:46,796 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:30:48,902 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:30:51,119 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:30:53,312 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:30:55,779 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:30:57,883 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:31:00,108 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:31:02,204 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:31:04,319 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:31:06,411 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:31:08,524 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:31:10,627 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:31:12,720 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:31:14,855 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:31:16,951 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:31:19,060 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:31:21,383 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:31:23,472 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:31:25,579 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:31:27,682 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:31:29,775 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:31:31,859 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:31:33,963 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:31:36,072 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:31:38,148 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:31:40,264 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:31:42,384 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:31:44,487 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:31:46,599 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 8 - Done: 0
# 2021-07-01 22:31
[DEBUG] lithops.future -- ExecutorID 51da88-0 | JobID M009 - Got status from call 00006 - Activation ID: d0a09aeec5fe - Time: 424.41 seconds
# 2021-07-01 22:37:04,160 [DEBUG] lithops.future -- ExecutorID 51da88-0 | JobID M009 - Got output from call 00006 - Activation ID: d0a09aeec5fe
# 2021-07-01 22:37:06,015 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 3 - Done: 5
# 2021-07-01 22:37:08,095 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 3 - Done: 5
# 2021-07-01 22:37:10,175 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 3 - Done: 5
# 2021-07-01 22:37:12,255 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 3 - Done: 5
# 2021-07-01 22:37:14,334 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:37:14,919 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:37:15,208 [DEBUG] lithops.future -- ExecutorID 51da88-0 | JobID M009 - Got status from call 00001 - Activation ID: 63ac86bfd5ab - Time: 437.98 seconds
# 2021-07-01 22:37:15,219 [DEBUG] lithops.future -- ExecutorID 51da88-0 | JobID M009 - Got output from call 00001 - Activation ID: 63ac86bfd5ab
# 2021-07-01 22:37:16,999 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:37:19,079 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:37:21,159 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:37:23,235 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:37:25,315 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:37:27,395 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:37:29,467 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:37:31,551 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:37:33,627 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:37:35,703 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:37:37,779 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:37:39,850 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:37:41,923 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:37:43,999 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:37:46,083 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:37:48,155 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:37:50,231 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:37:52,311 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:37:54,387 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:37:56,455 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:37:58,535 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:38:00,615 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:38:02,691 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:38:04,763 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:38:06,843 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:38:08,923 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:38:11,003 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:38:13,083 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:38:15,159 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:38:17,231 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:38:19,311 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:38:21,387 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:38:23,463 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:38:25,538 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:38:27,615 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:38:29,687 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:38:31,759 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:38:33,835 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:38:35,911 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:38:37,987 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:38:40,059 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:38:42,138 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:38:44,224 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 2 - Done: 6
# 2021-07-01 22:38:46,303 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 1 - Done: 7
# 2021-07-01 22:38:46,542 [DEBUG] lithops.future -- ExecutorID 51da88-0 | JobID M009 - Got status from call 00004 - Activation ID: 24a0eb188ae3 - Time: 529.00 seconds
# 2021-07-01 22:38:46,554 [DEBUG] lithops.future -- ExecutorID 51da88-0 | JobID M009 - Got output from call 00004 - Activation ID: 24a0eb188ae3
# 2021-07-01 22:38:46,875 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 1 - Done: 7
# 2021-07-01 22:38:48,951 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 1 - Done: 7
# 2021-07-01 22:38:51,027 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 1 - Done: 7
# 2021-07-01 22:38:53,103 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 1 - Done: 7
# 2021-07-01 22:38:55,183 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 1 - Done: 7
# 2021-07-01 22:38:57,268 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 1 - Done: 7
# 2021-07-01 22:38:59,347 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 1 - Done: 7
# 2021-07-01 22:39:01,415 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 1 - Done: 7
# 2021-07-01 22:39:03,491 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 1 - Done: 7
# 2021-07-01 22:39:05,571 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 1 - Done: 7
# 2021-07-01 22:39:07,647 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 1 - Done: 7
# 2021-07-01 22:39:09,723 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 1 - Done: 7
# 2021-07-01 22:39:11,799 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 1 - Done: 7
# 2021-07-01 22:39:13,879 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 1 - Done: 7
# 2021-07-01 22:39:15,955 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 1 - Done: 7
# 2021-07-01 22:39:18,031 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 1 - Done: 7
# 2021-07-01 22:39:20,111 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 1 - Done: 7
# 2021-07-01 22:39:22,191 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 1 - Done: 7
# 2021-07-01 22:39:24,263 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 1 - Done: 7
# 2021-07-01 22:39:26,343 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 1 - Done: 7
# 2021-07-01 22:39:28,419 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 1 - Done: 7
# 2021-07-01 22:39:30,499 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 1 - Done: 7
# 2021-07-01 22:39:32,580 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 1 - Done: 7
# 2021-07-01 22:39:34,662 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Pending: 0 - Running: 0 - Done: 8
# 2021-07-01 22:39:34,664 [DEBUG] lithops.monitor -- ExecutorID 51da88-0 | JobID M009 - Storage job monitor finished
# 2021-07-01 22:39:34,728 [DEBUG] lithops.future -- ExecutorID 51da88-0 | JobID M009 - Got status from call 00002 - Activation ID: 7d455979cd87 - Time: 578.70 seconds
# 2021-07-01 22:39:34,741 [DEBUG] lithops.future -- ExecutorID 51da88-0 | JobID M009 - Got output from call 00002 - Activation ID: 7d455979cd87
# 2021-07-01 22:39:34,745 [DEBUG] lithops.serverless.backends.k8s.k8s -- Deleting job lithops-51da88-0-m009
# 2021-07-01 22:39:34,790 [INFO] lithops.executors -- ExecutorID 51da88-0 - Cleaning temporary data
# 2021-07-01 22:39:34,815 [DEBUG] lithops.executors -- ExecutorID 51da88-0 Finished getting results

# %% [markdown]
# ## Visualization of results

# %%
import io
tile = random.choice(tiles)
obj = io.BytesIO(cloud_storage.get_object(bucket=BUCKET, key=f'etc/{tile}_ETC.tif'))

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots()

with rasterio.open(obj) as src:
    arr = src.read(1, out_shape=(src.height, src.width))
    ax.set_title(tile)
    img = ax.imshow(arr, cmap='Greens')
    fig.colorbar(img, shrink=0.5)

fig.set_size_inches(18.5, 10.5)
plt.show()

obj.seek(0)
# Out:
# 0

# %% [markdown]
# ### Utility functions

# %% [markdown]
# Remove intermediate data

# %%
# keys = cloud_storage.list_keys(bucket=BUCKET, prefix='')
# keys

# %%
# for key in keys:
#     cloud_storage.delete_object(bucket=BUCKET, key=key)
