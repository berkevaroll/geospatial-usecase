# %% [markdown]
# # Water consumption (Minimal testing notebook)

# %% [markdown]
# IMPORTANT NOTE: ALL DE INPUT DATA MUST BE STORED IN THE STORAGE BACKEND

# %% [markdown]
# - DOWNLOAD THE DATA FROM https://cloudlab.urv.cat/josep/geospatial_usecase AND UPLOAD IT TO THE STORAGE BACKEND WITH:
#
# lithops storage put MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif geospatial-usecase
#
# lithops storage put MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif geospatial-usecase
#
# lithops storage put MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif geospatial-usecase
#
# lithops storage put MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif geospatial-usecase
#
# lithops storage put MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif geospatial-usecase
#
# lithops storage put MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif geospatial-usecase
#
# lithops storage put MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif geospatial-usecase
#
# lithops storage put MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif geospatial-usecase

# %% [markdown]
# The current notebook computes an interpolation of temperatures in each pixel based on SIAM extracted data.

# %% [markdown]
# A ~/.lithops/config correctly configured located at home directory is needed in order to connect with IBM Cloud. More information at https://github.com/lithops-cloud/lithops/tree/master/config.

# %%
from collections import defaultdict
from cloudbutton_geospatial.io_utils.plot import plot_random_blocks, plot_results
from rasterio.windows import Window
from scipy.spatial import distance_matrix
from shapely.geometry import Point, MultiPoint, box
from pprint import pprint
from functools import partial
from lithops import Storage
import io
import os
import lithops
import requests
import shutil
import numpy as np
import pandas as pd
import math
import rasterio
import random

# %% [markdown]
# ## Global parameters

# %% [markdown]
# Area outside the processed tile that we want to consider for taking SIAM stations into account:

# %%
AREA_OF_INFLUENCE = 4000

# %% [markdown]
# Lithops Variables:

# %%
BUCKET = 'geospatial-usecase'
COMPUTE_BACKEND = 'ibm_cf'
STORAGE_BACKEND = 'ibm_cos'
RUNTIME = 'jsampe/lithops-ibmcf-geospatial-v38:06'

# %% [markdown]
# Split tile into SPLITS$^2$ chunks:

# %%
SPLITS = 3

# %% [markdown]
# Correlation coefficient between elevation and temperature:

# %%
r = -0.0056

# %% [markdown]
# Elevation to interpolate temperature:

# %%
zdet = 2000

# %% [markdown]
# Day of year to calculate solar irradiation:

# %%
DAY_OF_YEAR = 50

# %% [markdown]
# Object storage key prefix, to keep objects organized:

# %%
cloud_storage = Storage(backend=STORAGE_BACKEND)

# %% [markdown]
# ## Data preparation

# %% [markdown]
# This section fetches and uploads to COS the metadata used in the workflow. It can be skipped if the data is already in COS.

# %% [markdown]
# ### SIAM data

# %%
url = 'http://siam.imida.es/apex/f?p=101:47:493289053024037:CSV::::'
# url = 'http://siam.imida.es/apex/f?p=101:48:2555846978143339:CSV::::'
siam_data = requests.get(url)
with open('siam_data.csv', 'wb') as siam_data_file:
    siam_data_file.write(siam_data.content)

# %%
def guess_nearest(x, y, field, stations):
    '''
    Compute field value at a given x,y point by getting the value of the closest station 
    '''
    from shapely.ops import nearest_points
    stations_of_interest = stations[(stations[field] != '-') & ((stations['X'] != x) | (stations['Y'] != y))]
    points = MultiPoint(stations_of_interest.apply(lambda row: Point(row['X'], row['Y']), axis=1 ).array)
    nearest = nearest_points(Point(x,y), points)[1]
    val = stations_of_interest[(stations_of_interest['X'] == nearest.x) &
                                (stations_of_interest['Y'] == nearest.y)]

    return stations_of_interest[(stations_of_interest['X'] == nearest.x) &
                                (stations_of_interest['Y'] == nearest.y)][field].iloc[0]

# %% [markdown]
# Append locations of SIAM stations to previously downloaded data and write results to a CSV:

# %%
columns = {
    'Estación': 'COD',
    'Tmed <br> (ºC)': 'temp',
    'Hrmed <br> (%)': 'hr',
    'Vvmed <br> (m/seg)': 'v',
    'Eti.': 'dir',
    'Radmed <br> (w/m2)': 'rad',
    'Dvmed <br>  (º)': 'dir_deg'
}

siam_data = pd.read_csv('siam_data.csv', encoding='iso-8859-1',
                        sep=';', decimal=',', thousands='.', na_values = '-')
siam_data = siam_data[columns.keys()].rename(columns=columns)
siam_locations = pd.read_csv('siam_locations.csv', encoding='iso-8859-1', sep=';', decimal = ',', thousands='.')
siam = pd.merge(siam_locations, siam_data, on='COD')
siam['tdet'] = siam['temp'] + r * (zdet - siam['Cota'].to_numpy())
siam = siam[['X', 'Y', 'Cota', 'temp', 'hr', 'tdet', 'v'] + list(columns.values())]
# Guess wind direction of undefined values
siam['dir_deg'] = siam.apply(lambda row: row['dir_deg'] 
                                     if not math.isnan(row['dir_deg'])
                                     else guess_nearest(row['X'], row['Y'], 'dir_deg', siam), axis=1)
# Guess radiation of undefined values
siam['rad'] = siam.apply(lambda row: row['rad'] 
                                     if not math.isnan(row['rad'])
                                     else guess_nearest(row['X'], row['Y'], 'rad', siam), axis=1)
siam.to_csv('siam.csv', index=False)

# %% [markdown]
# Upload the output CSV to COS:

# %%
with open('siam.csv', 'rb') as siam_out_file:
    cloud_storage.put_object(bucket=BUCKET, key='siam.csv', body=siam_out_file)

# %% [markdown]
# Upload the Sahape file

# %%
with open('shapefiles/shapefile.zip', 'rb') as shapefile:
    cloud_storage.put_object(bucket=BUCKET, key='shapefile.zip', body=shapefile)

# %% [markdown]
# ## Serverless computation

# %% [markdown]
# Input MDT tiles to process:

# %%
tiles = [os.path.splitext(os.path.basename(key))[0]
         for key in cloud_storage.list_keys(bucket=BUCKET, prefix='MDT')]
tiles
# Out:
# ['PNOA_MDT05_ETRS89_HU30_0891_LID',
#  'PNOA_MDT05_ETRS89_HU30_0892_LID',
#  'PNOA_MDT05_ETRS89_HU30_0912_LID',
#  'PNOA_MDT05_ETRS89_HU30_0913_LID',
#  'PNOA_MDT05_ETRS89_HU30_0933_LID',
#  'PNOA_MDT05_ETRS89_HU30_0934_LID',
#  'PNOA_MDT05_ETRS89_HU30_0954_LID',
#  'PNOA_MDT05_ETRS89_HU30_0955_LID']

# %%
# DEBUG
#tiles = ['PNOA_MDT05_ETRS89_HU30_0891_LID','PNOA_MDT05_ETRS89_HU30_0892_LID']
#tiles

# %% [markdown]
# Compute solar irradiation given a day of year using GRASS libraries:

# %%
def compute_solar_irradiation(inputFile, outputFile, crs='32630'):
    # Define grass working set
    GRASS_GISDB = 'grassdata'
    GRASS_LOCATION = 'GEOPROCESSING'
    GRASS_MAPSET = 'PERMANENT'
    GRASS_ELEVATIONS_FILENAME = 'ELEVATIONS'
    

    os.environ['GRASSBIN'] = 'grass76'
    from grass_session import Session
    import grass.script as gscript
    from grass.pygrass.modules.shortcuts import general as g
    from grass.pygrass.modules.shortcuts import raster as r
    import re
    
    os.environ.update(dict(GRASS_COMPRESS_NULLS='1'))
    
    # Clean previously processed data
    if os.path.isdir(GRASS_GISDB):
        shutil.rmtree(GRASS_GISDB)
    with Session(gisdb=GRASS_GISDB, location=GRASS_LOCATION, mapset=GRASS_MAPSET, create_opts='EPSG:32630') as ses:
    
        # Set project projection to match elevation raster projection
        g.proj(epsg=crs, flags='c') 
    
        # Load raster file into working directory
        r.import_(input=inputFile, 
                  output=GRASS_ELEVATIONS_FILENAME, 
                  flags='o')    
        
        # Set project region to match raster region
        g.region(raster=GRASS_ELEVATIONS_FILENAME, flags='s')    
        # Calculate solar irradiation
        gscript.run_command('r.slope.aspect', elevation=GRASS_ELEVATIONS_FILENAME,
                            slope='slope', aspect='aspect')
        gscript.run_command('r.sun', elevation=GRASS_ELEVATIONS_FILENAME,
                            slope='slope', aspect='aspect', beam_rad='beam',
                            step=1, day=DAY_OF_YEAR)
        
        # Get extraterrestrial irradiation from history metadata
        regex = re.compile(r'\d+\.\d+')
        output = gscript.read_command("r.info", flags="h", map=["beam"])
        splits = str(output).split('\n')
        line = next(filter(lambda line: 'Extraterrestrial' in line, splits))
        extraterrestrial_irradiance = float(regex.search(line)[0])
        
        # Export generated results into a GeoTiff file
        if os.path.isfile(outputFile):
            os.remove(outputFile)
            
        r.out_gdal(input='beam', output=outputFile)
        
        return extraterrestrial_irradiance

# %% [markdown]
# Get stations contained in the area of interest:

# %%
def filter_stations(bounds, stations):
    total_points = MultiPoint([Point(x,y) for x, y in stations[['X', 'Y']].to_numpy()])
    intersection = bounds.buffer(AREA_OF_INFLUENCE).intersection(total_points)
    
    return stations[[ intersection.contains(point) for point in total_points]]

# %% [markdown]
# Inverse Distance Weighting interpolation:

# %%
def compute_basic_interpolation(shape, stations, field_value, offset = (0,0)):
    station_pixels = [[pixel[0], pixel[1]] for pixel in stations['pixel'].to_numpy()]
    
    # Get an array where each position represents pixel coordinates
    tile_pixels = np.indices(shape).transpose(1,2,0).reshape(shape[0]*shape[1], 2) + offset
    dist = distance_matrix(station_pixels, tile_pixels)
    weights = np.where(dist == 0, np.finfo('float32').max, 1.0 / dist )
    weights /=  weights.sum(axis=0)
    
    return np.dot(weights.T, stations[field_value].to_numpy()).reshape(shape).astype('float32')

# %% [markdown]
# Interpolate temperatures from a subset of the tile:

# %%
def radiation_interpolation(obj, block_x, block_y, splits, storage):
    tile_key = os.path.basename(obj.key)
    tile_id, _ = os.path.splitext(tile_key)
    
    with rasterio.open(obj.data_stream) as src:
        transform = src.transform
        
        # Compute working window
        step_w = src.width / splits
        step_h = src.height / splits
        
        offset_h = round(step_h * block_x)
        offset_w = round(step_w * block_y)
        
        profile = src.profile
        width = math.ceil(step_w * (block_y + 1) - offset_w)
        height = math.ceil(step_h * (block_x + 1) - offset_h)
        
        profile.update(width=width)
        profile.update(height=height)
        
        window = Window(offset_w, offset_h, width, height)
        
        with rasterio.open('input', 'w', **profile) as dest:
            dest.write(src.read(window=window))
        
    # Stores global irradiation at "output", it also returns extraterrestrial irradiation
    extraterrestrial_irradiation = compute_solar_irradiation('input', 'output')
        
    # Create and store a raster with extraterrestrial_irradiation
    with rasterio.open('extr', 'w', **profile) as dest:
        data = np.full((height, width), extraterrestrial_irradiation, dtype='float32')
        dest.write(data, 1)
        
    out_key = os.path.join('tmp', 'extrad', tile_id, f'chunk_{block_x}-{block_y}') + '.tif'
    with open('extr', 'rb') as out_file:
        storage.put_object(BUCKET, out_key, out_file)
    
    out_key = os.path.join('tmp', 'rad', tile_id, f'chunk_{block_x}-{block_y}') + '.tif'
    with open('output', 'rb') as out_file:
        storage.put_object(BUCKET, out_key, out_file)
    
    return out_key

# %%
def map_interpolation(obj, block_x, block_y, splits, data_field, storage):    
    tile_key = os.path.basename(obj.key)
    tile_id, _ = os.path.splitext(tile_key)
          
    siam_stream = storage.get_object(BUCKET, 'siam.csv', stream=True)
    siam = pd.read_csv(siam_stream)
    
    with rasterio.open(obj.data_stream) as src:
        transform = src.transform
        
        # Compute working window
        step_w = src.width / splits
        step_h = src.height / splits
        
        offset_h = round(step_h * block_x)
        offset_w = round(step_w * block_y)
        
        profile = src.profile
        
        width = math.ceil(step_w * (block_y + 1) - offset_w)
        height = math.ceil(step_h * (block_x + 1) - offset_h)
        
        profile.update(width=width)
        profile.update(height=height)
        
        window = Window(offset_w,offset_h, width, height)
        
        # Filter desired stations
        bounding_rect = box(src.bounds.left, src.bounds.top, src.bounds.right, src.bounds.bottom)
        filtered = pd.DataFrame(filter_stations(bounding_rect, siam))
        filtered['pixel'] = filtered.apply(
            lambda station: rasterio.transform.rowcol(transform, station['X'], station['Y']), axis=1)
        
        # Interpolate and write results 
        with rasterio.open('output', 'w', **profile) as dest:
            if data_field == 'temp':
                elevations = src.read(1, window=window) # Get elevations content
                interpolation = compute_basic_interpolation(elevations.shape, filtered,
                                                            'tdet', (offset_h, offset_w))
                interpolation += r * (elevations - zdet)
                dest.write(np.where(elevations == src.nodata, np.nan, interpolation), 1)
            else:
                interpolation = compute_basic_interpolation((height, width),
                                                            filtered, 
                                                            'hr' if data_field == 'humi' else 'v', 
                                                            (offset_h, offset_w))
                dest.write(interpolation, 1)

    # Export results to storage
    out_key = os.path.join('tmp', data_field, tile_id, 'chunk_{}-{}'.format(block_x, block_y)) + '.tif'
    with open('output', 'rb') as output_file:
        storage.put_object(BUCKET, out_key, output_file)
    
    return out_key

# %% [markdown]
# Lithops serverless computation:

# %%
iterdata = [('{}/MDT/{}.tif'.format(BUCKET, tile), i, j) 
            for i in range(SPLITS) for j in range(SPLITS) for tile in tiles]

# %%
pprint(iterdata)
print('Total functions: {} tiles * ({}^2) splits * 4 calculations = {}'.format(
    len(tiles), SPLITS, len(iterdata) * 4))
# Out:
# [('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif', 0, 0),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif', 0, 0),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif', 0, 0),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif', 0, 0),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif', 0, 0),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif', 0, 0),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif', 0, 0),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif', 0, 0),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif', 0, 1),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif', 0, 1),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif', 0, 1),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif', 0, 1),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif', 0, 1),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif', 0, 1),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif', 0, 1),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif', 0, 1),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif', 0, 2),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif', 0, 2),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif', 0, 2),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif', 0, 2),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif', 0, 2),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif', 0, 2),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif', 0, 2),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif', 0, 2),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif', 1, 0),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif', 1, 0),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif', 1, 0),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif', 1, 0),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif', 1, 0),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif', 1, 0),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif', 1, 0),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif', 1, 0),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif', 1, 1),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif', 1, 1),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif', 1, 1),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif', 1, 1),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif', 1, 1),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif', 1, 1),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif', 1, 1),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif', 1, 1),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif', 1, 2),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif', 1, 2),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif', 1, 2),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif', 1, 2),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif', 1, 2),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif', 1, 2),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif', 1, 2),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif', 1, 2),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif', 2, 0),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif', 2, 0),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif', 2, 0),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif', 2, 0),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif', 2, 0),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif', 2, 0),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif', 2, 0),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif', 2, 0),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif', 2, 1),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif', 2, 1),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif', 2, 1),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif', 2, 1),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif', 2, 1),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif', 2, 1),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif', 2, 1),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif', 2, 1),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif', 2, 2),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif', 2, 2),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif', 2, 2),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif', 2, 2),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif', 2, 2),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif', 2, 2),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif', 2, 2),
#  ('geospatial-usecase/MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif', 2, 2)]
# Total functions: 8 tiles * (3^2) splits * 4 calculations = 288

# %%
fexec = lithops.FunctionExecutor(backend=COMPUTE_BACKEND, storage=STORAGE_BACKEND,
                                 runtime=RUNTIME, log_level="DEBUG")

fexec.map(radiation_interpolation, iterdata, extra_args=(SPLITS,), runtime_memory=2048)

fexec.map(map_interpolation, iterdata, extra_args=(SPLITS,'temp'), runtime_memory=1024)

fexec.map(map_interpolation, iterdata, extra_args=(SPLITS,'humi'), runtime_memory=1024)

fexec.map(map_interpolation, iterdata, extra_args=(SPLITS,'wind'), runtime_memory=1024)

out_chunks = fexec.get_result()
# Out:
# 2021-09-21 22:43:20,667 [INFO] lithops.config -- Lithops v2.5.1.dev0
# 2021-09-21 22:43:20,668 [DEBUG] lithops.config -- Loading configuration from /home/josep/.lithops/config
# 2021-09-21 22:43:20,679 [DEBUG] lithops.config -- Loading Serverless backend module: ibm_cf
# 2021-09-21 22:43:20,682 [DEBUG] lithops.config -- Loading Storage backend module: ibm_cos
# 2021-09-21 22:43:20,682 [DEBUG] lithops.storage.backends.ibm_cos.ibm_cos -- Creating IBM COS client
# 2021-09-21 22:43:20,683 [DEBUG] lithops.storage.backends.ibm_cos.ibm_cos -- Set IBM COS Endpoint to https://s3.us-east.cloud-object-storage.appdomain.cloud
# 2021-09-21 22:43:20,684 [DEBUG] lithops.storage.backends.ibm_cos.ibm_cos -- Using access_key and secret_key
# 2021-09-21 22:43:20,689 [INFO] lithops.storage.backends.ibm_cos.ibm_cos -- IBM COS Storage client created - Region: us-east
# 2021-09-21 22:43:20,690 [DEBUG] lithops.serverless.backends.ibm_cf.ibm_cf -- Creating IBM Cloud Functions client
# 2021-09-21 22:43:20,691 [DEBUG] lithops.serverless.backends.ibm_cf.ibm_cf -- Set IBM CF Namespace to josep_dev_us_east
# 2021-09-21 22:43:20,691 [DEBUG] lithops.serverless.backends.ibm_cf.ibm_cf -- Set IBM CF Endpoint to https://us-east.functions.cloud.ibm.com
# 2021-09-21 22:43:20,692 [INFO] lithops.serverless.backends.ibm_cf.ibm_cf -- IBM CF client created - Region: us-east - Namespace: josep_dev_us_east
# 2021-09-21 22:43:20,693 [DEBUG] lithops.invokers -- ExecutorID dd8057-0 - Total workers: 1200
# 2021-09-21 22:43:20,694 [DEBUG] lithops.invokers -- ExecutorID dd8057-0 - Serverless invoker created
# 2021-09-21 22:43:20,694 [DEBUG] lithops.executors -- Function executor for ibm_cf created with ID: dd8057-0
# 2021-09-21 22:43:20,695 [INFO] lithops.invokers -- ExecutorID dd8057-0 | JobID M000 - Selected Runtime: jsampe/lithops-ibmcf-geospatial-v38:06 - 2048MB
# 2021-09-21 22:43:20,695 [DEBUG] lithops.storage.storage -- Runtime metadata not found in local cache. Retrieving it from storage
# 2021-09-21 22:43:20,696 [DEBUG] lithops.storage.storage -- Trying to download runtime metadata from: ibm_cos://lithops-data-us-east/lithops.runtimes/2.5.1.dev0/ibm_cf/us-east/josep_dev_us_east/jsampe_lithops-ibmcf-geospatial-v38_06_2048MB.meta.json
# 2021-09-21 22:43:21,332 [DEBUG] lithops.storage.storage -- Runtime metadata not found in storage
# 2021-09-21 22:43:21,333 [INFO] lithops.invokers -- Runtime jsampe/lithops-ibmcf-geospatial-v38:06 with 2048MB is not yet installed
# 2021-09-21 22:43:21,334 [INFO] lithops.serverless.backends.ibm_cf.ibm_cf -- Creating new Lithops runtime based on Docker image jsampe/lithops-ibmcf-geospatial-v38:06
# 2021-09-21 22:43:21,335 [DEBUG] lithops.libs.openwhisk.client -- Creating functions package lithops_v2.5.1.dev0_FRGd
# 2021-09-21 22:43:22,372 [DEBUG] lithops.libs.openwhisk.client -- Package lithops_v2.5.1.dev0_FRGd: resource already exists
# 2021-09-21 22:43:22,374 [DEBUG] lithops.utils -- Creating function handler zip in /home/josep/data/dev-workspace/geospatial-usecase/lithops_ibmcf.zip
# 2021-09-21 22:43:22,421 [DEBUG] lithops.libs.openwhisk.client -- Creating function action: jsampe_lithops-ibmcf-geospatial-v38_06_2048MB
# 2021-09-21 22:43:23,713 [DEBUG] lithops.libs.openwhisk.client -- OK --> Created action jsampe_lithops-ibmcf-geospatial-v38_06_2048MB
# 2021-09-21 22:43:23,714 [DEBUG] lithops.serverless.backends.ibm_cf.ibm_cf -- Extracting Python modules list from: jsampe/lithops-ibmcf-geospatial-v38:06
# 2021-09-21 22:43:34,261 [DEBUG] lithops.storage.storage -- Uploading runtime metadata to: ibm_cos://lithops-data-us-east/lithops.runtimes/2.5.1.dev0/ibm_cf/us-east/josep_dev_us_east/jsampe_lithops-ibmcf-geospatial-v38_06_2048MB.meta.json
# 2021-09-21 22:43:34,711 [DEBUG] lithops.storage.backends.ibm_cos.ibm_cos -- PUT Object lithops.runtimes/2.5.1.dev0/ibm_cf/us-east/josep_dev_us_east/jsampe_lithops-ibmcf-geospatial-v38_06_2048MB.meta.json - Size: 6.9KiB - OK
# 2021-09-21 22:43:34,713 [DEBUG] lithops.storage.storage -- Storing runtime metadata into local cache: /home/josep/.lithops/cache/lithops.runtimes/2.5.1.dev0/ibm_cf/us-east/josep_dev_us_east/jsampe_lithops-ibmcf-geospatial-v38_06_2048MB.meta.json
# 2021-09-21 22:43:34,715 [DEBUG] lithops.job.job -- ExecutorID dd8057-0 | JobID M000 - Calling map on partitions from object storage flow
# 2021-09-21 22:43:34,715 [DEBUG] lithops.job.partitioner -- Parsing input data
# 2021-09-21 22:43:34,716 [DEBUG] lithops.job.partitioner -- Chunk size and chunk number not set
# 2021-09-21 22:43:34,717 [DEBUG] lithops.job.partitioner -- Listing objects in 'ibm_cos://geospatial-usecase/MDT'
# 2021-09-21 22:43:34,967 [DEBUG] lithops.job.partitioner -- Total objects found: 8
# 2021-09-21 22:43:34,968 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-09-21 22:43:34,969 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-09-21 22:43:34,970 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-09-21 22:43:34,971 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-09-21 22:43:34,972 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-09-21 22:43:34,972 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-09-21 22:43:34,973 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-09-21 22:43:34,973 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-09-21 22:43:34,974 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-09-21 22:43:34,974 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-09-21 22:43:34,975 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-09-21 22:43:34,975 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-09-21 22:43:34,977 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-09-21 22:43:34,978 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-09-21 22:43:34,978 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-09-21 22:43:34,979 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-09-21 22:43:34,980 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-09-21 22:43:34,980 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-09-21 22:43:34,980 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-09-21 22:43:34,981 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-09-21 22:43:34,982 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-09-21 22:43:34,982 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-09-21 22:43:34,982 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-09-21 22:43:34,983 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-09-21 22:43:34,983 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-09-21 22:43:34,984 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-09-21 22:43:34,984 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-09-21 22:43:34,984 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-09-21 22:43:34,985 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-09-21 22:43:34,985 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-09-21 22:43:34,987 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-09-21 22:43:34,988 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-09-21 22:43:34,988 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-09-21 22:43:34,988 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-09-21 22:43:34,989 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-09-21 22:43:34,989 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-09-21 22:43:34,989 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-09-21 22:43:34,990 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-09-21 22:43:34,990 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-09-21 22:43:34,991 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-09-21 22:43:34,991 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-09-21 22:43:34,991 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-09-21 22:43:34,992 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-09-21 22:43:34,992 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-09-21 22:43:34,992 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-09-21 22:43:34,993 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-09-21 22:43:34,993 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-09-21 22:43:34,993 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-09-21 22:43:34,994 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-09-21 22:43:34,994 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-09-21 22:43:34,994 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-09-21 22:43:34,995 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-09-21 22:43:34,997 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-09-21 22:43:34,998 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-09-21 22:43:34,998 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-09-21 22:43:34,999 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-09-21 22:43:34,999 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-09-21 22:43:34,999 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-09-21 22:43:35,000 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-09-21 22:43:35,000 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-09-21 22:43:35,001 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-09-21 22:43:35,001 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-09-21 22:43:35,003 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-09-21 22:43:35,003 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-09-21 22:43:35,004 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-09-21 22:43:35,004 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-09-21 22:43:35,004 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-09-21 22:43:35,005 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-09-21 22:43:35,005 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-09-21 22:43:35,007 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-09-21 22:43:35,009 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-09-21 22:43:35,009 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-09-21 22:43:35,010 [DEBUG] lithops.job.job -- ExecutorID dd8057-0 | JobID M000 - Serializing function and data
# 2021-09-21 22:43:35,044 [DEBUG] lithops.job.serialize -- Referenced modules: /usr/local/lib/python3.8/dist-packages/rasterio/__init__.py, /usr/lib/python3.8/re.py, /home/josep/.local/lib/python3.8/site-packages/numpy/__init__.py, /home/josep/data/dev-workspace/lithops/lithops/lithops/storage/utils.py, math, /usr/lib/python3.8/os.py, /usr/local/lib/python3.8/dist-packages/rasterio/windows.py, /usr/lib/python3.8/shutil.py
# 2021-09-21 22:43:35,045 [DEBUG] lithops.job.serialize -- Modules to transmit: None
# 2021-09-21 22:43:35,046 [DEBUG] lithops.job.job -- ExecutorID dd8057-0 | JobID M000 - Uploading function and modules to the storage backend
# 2021-09-21 22:43:35,346 [DEBUG] lithops.storage.backends.ibm_cos.ibm_cos -- PUT Object lithops.jobs/dd8057-0/f8b1bcea1b697e5089dddc647886a209.func.pickle - Size: 3.3KiB - OK
# 2021-09-21 22:43:35,347 [DEBUG] lithops.job.job -- ExecutorID dd8057-0 | JobID
[DEBUG] lithops.job.job -- ExecutorID dd8057-0 | JobID M001 - Calling map on partitions from object storage flow
# 2021-09-21 22:44:09,015 [DEBUG] lithops.job.partitioner -- Parsing input data
# 2021-09-21 22:44:09,016 [DEBUG] lithops.job.partitioner -- Chunk size and chunk number not set
# 2021-09-21 22:44:09,018 [DEBUG] lithops.job.partitioner -- Listing objects in 'ibm_cos://geospatial-usecase/MDT'
# 2021-09-21 22:44:09,235 [DEBUG] lithops.job.partitioner -- Total objects found: 8
# 2021-09-21 22:44:09,236 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-09-21 22:44:09,237 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-09-21 22:44:09,238 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-09-21 22:44:09,239 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-09-21 22:44:09,240 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-09-21 22:44:09,241 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-09-21 22:44:09,241 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-09-21 22:44:09,242 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-09-21 22:44:09,242 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-09-21 22:44:09,243 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-09-21 22:44:09,244 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-09-21 22:44:09,244 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-09-21 22:44:09,245 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-09-21 22:44:09,245 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-09-21 22:44:09,246 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-09-21 22:44:09,247 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-09-21 22:44:09,247 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-09-21 22:44:09,247 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-09-21 22:44:09,250 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-09-21 22:44:09,251 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-09-21 22:44:09,251 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-09-21 22:44:09,251 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-09-21 22:44:09,252 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-09-21 22:44:09,252 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-09-21 22:44:09,252 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-09-21 22:44:09,253 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-09-21 22:44:09,254 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-09-21 22:44:09,254 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-09-21 22:44:09,255 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-09-21 22:44:09,255 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-09-21 22:44:09,255 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-09-21 22:44:09,256 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-09-21 22:44:09,256 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-09-21 22:44:09,257 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-09-21 22:44:09,257 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-09-21 22:44:09,257 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-09-21 22:44:09,258 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-09-21 22:44:09,259 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-09-21 22:44:09,260 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-09-21 22:44:09,260 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-09-21 22:44:09,260 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-09-21 22:44:09,261 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-09-21 22:44:09,261 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-09-21 22:44:09,262 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-09-21 22:44:09,262 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-09-21 22:44:09,262 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-09-21 22:44:09,264 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-09-21 22:44:09,264 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-09-21 22:44:09,265 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-09-21 22:44:09,265 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-09-21 22:44:09,266 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-09-21 22:44:09,266 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-09-21 22:44:09,266 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-09-21 22:44:09,267 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-09-21 22:44:09,268 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-09-21 22:44:09,269 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-09-21 22:44:09,270 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-09-21 22:44:09,273 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-09-21 22:44:09,274 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-09-21 22:44:09,275 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-09-21 22:44:09,277 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-09-21 22:44:09,279 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-09-21 22:44:09,279 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-09-21 22:44:09,279 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-09-21 22:44:09,280 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-09-21 22:44:09,281 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0892_LID.tif (63.1MiB)
# 2021-09-21 22:44:09,281 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0912_LID.tif (61.9MiB)
# 2021-09-21 22:44:09,281 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0913_LID.tif (56.3MiB)
# 2021-09-21 22:44:09,282 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0933_LID.tif (62.2MiB)
# 2021-09-21 22:44:09,282 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0934_LID.tif (60.1MiB)
# 2021-09-21 22:44:09,283 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0954_LID.tif (57.3MiB)
# 2021-09-21 22:44:09,283 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0955_LID.tif (53.6MiB)
# 2021-09-21 22:44:09,284 [DEBUG] lithops.job.job -- ExecutorID dd8057-0 | JobID M001 - Serializing function and data
# 2021-09-21 22:44:09,324 [DEBUG] lithops.job.serialize -- Referenced modules: /usr/local/lib/python3.8/dist-packages/rasterio/__init__.py, /usr/local/lib/python3.8/dist-packages/shapely/geometry/geo.py, /usr/local/lib/python3.8/dist-packages/shapely/geometry/polygon.py, /home/josep/.local/lib/python3.8/site-packages/numpy/__init__.py, /home/josep/data/dev-workspace/lithops/lithops/lithops/storage/utils.py, math, /usr/local/lib/python3.8/dist-packages/pandas/__init__.py, /usr/lib/python3.8/os.py, /usr/local/lib/python3.8/dist-packages/rasterio/windows.py, /usr/local/lib/python3.8/dist-packages/shapely/geometry/multipoint.py, /home/josep/.local/lib/python3.8/site-packages/scipy/spatial/kdtree.py
# 2021-09-21 22:44:09,325 [DEBUG] lithops.job.serialize -- Modules to transmit: None
# 2021-09-21 22:44:09,326 [DEBUG] lithops.job.job -- ExecutorID dd8057-0 | JobID M001 - Uploading function and modules to the storage backend
# 2021-09-21 22:44:09,606 [DEBUG] lithops.monitor -- ExecutorID dd8057-0 - Pending: 9 - Running: 63 - Done: 0
# 2021-09-21 22:44:09,607 [DEBUG] lithops.storage.backends.ibm_cos.ibm_cos -- PUT Object lithops.jobs/dd8057-0/5c90e02cd7fc1163f4bb0ab4a959f9ab.func.pickle - Size: 3.5KiB - OK
# 2021-09-21 22:44:09,609 [DEBUG] lithops.job.job -- ExecutorID dd8057-0 | JobID M001 - Data per activation is < 8.0KiB. Passing data through invocation payload
# 2021-09-21 22:44:09,610 [INFO] lithops.invokers -- ExecutorID dd8057-0 | JobID M001 - Starting function invocation: map_interpolation() - Total: 72 activations
# 2021-09-21 22:44:09,611 [DEBUG] lithops.invokers -- ExecutorID dd8057-0 | JobID M001 - Chunksize: 1 - Worker processes: 1
# 2021-09-21 22:44:09,613 [DEBUG] lithops.invokers -- ExecutorID dd8057-0 | JobID M001 - Free workers: 1128 - Going to run 72 activations in 72 workers
# 2021-09-21 22:44:09,615 [INFO] lithops.invokers -- ExecutorID dd8057-0 | JobID M001 - View execution logs at /tmp/lithops/logs/dd8057-0-M001.log
# 2021-09-21 22:44:09,621 [INFO] lithops.invokers -- ExecutorID dd8057-0 | JobID M002 - Selected Runtime: jsampe/lithops-ibmcf-geospatial-v38:06 - 1024MB
# 2021-09-21 22:44:09,625 [DEBUG] lithops.storage.storage -- Runtime metadata found in local disk cache
# 2021-09-21 22:44:09,628 [DEBUG] lithops.job.job -- ExecutorID dd8057-0 | JobID M002 - Calling map on partitions from object storage flow
# 2021-09-21 22:44:09,630 [DEBUG] lithops.job.partitioner -- Parsing input data
# 2021-09-21 22:44:09,632 [DEBUG] lithops.job.partitioner -- Chunk size and chunk number not set
# 2021-09-21 22:44:09,636 [DEBUG] lithops.job.partitioner -- Listing objects in 'ibm_cos://geospatial-usecase/MDT'
# 2021-09-21 22:44:09,892 [DEBUG] lithops.job.partitioner -- Total objects found: 8
# 2021-09-21 22:44:09,893 [DEBUG] lithops.job.partitioner -- Creating 1 partitions from object MDT/PNOA_MDT05_ETRS89_HU30_0891_LID.tif (62.6MiB)
# 2021-09-21 22:44:09
[DEBUG] lithops.monitor -- ExecutorID dd8057-0 - Pending: 0 - Running: 0 - Done: 288
# 2021-09-21 22:48:19,162 [DEBUG] lithops.monitor -- ExecutorID dd8057-0 - Storage job monitor finished
# 2021-09-21 22:48:19,831 [DEBUG] lithops.future -- ExecutorID dd8057-0 | JobID M000 - Got status from call 00019 - Activation ID: 9bb67d444935438db67d444935538d5a - Time: 268.08 seconds
# 2021-09-21 22:48:19,969 [DEBUG] lithops.future -- ExecutorID dd8057-0 | JobID M000 - Got output from call 00019 - Activation ID: 9bb67d444935438db67d444935538d5a
# 2021-09-21 22:48:19,972 [INFO] lithops.executors -- ExecutorID dd8057-0 - Cleaning temporary data
# 2021-09-21 22:48:19,989 [DEBUG] lithops.executors -- ExecutorID dd8057-0 - Finished getting results

# %% [markdown]
# Join split subsets into a tile:

# %%
def gather_blocks(tile, splits, data_field, storage):

    from rasterio.windows import Window
    
    # Get width and height from original tile
    with rasterio.open(storage.get_object(bucket=BUCKET, key=f'MDT/{tile}.tif', stream=True)) as og:
        height = og.profile['height']
        width = og.profile['width']
    
    chunk_tiles = storage.list_keys(bucket=BUCKET, prefix=f'tmp/{data_field}/{tile}/chunk')
        
    # Open first object to obtain profile metadata
    with rasterio.open(storage.get_object(bucket=BUCKET, key=chunk_tiles[0], stream=True)) as src:
        profile = src.profile
        profile.update(width=width)
        profile.update(height=height)

    # Iterate each object and print its block into the destination file
    with rasterio.open("output", "w", **profile) as dest: 
        for chunk in chunk_tiles:
            j, i = os.path.splitext(os.path.basename(chunk))[0].rsplit('_')[1].split('-')
            j, i = int(j), int(i)
            with rasterio.open(storage.get_object(bucket=BUCKET, key=chunk, stream=True)) as src:
                step_w = math.floor(width / splits)
                step_h = math.floor(height / splits)
                curr_window = Window(round(step_w * i), round(step_h * j), src.width, src.height)
                content = src.read(1)
                dest.write(content, 1, window=curr_window)
            # storage.delete_object(bucket=BUCKET, key=chunk)
    
    output_key = os.path.join('tmp', data_field, tile, '_'.join([tile, data_field.upper()+'.tif']))
    with open('output', 'rb') as out_file:
        storage.put_object(bucket=BUCKET, key=output_key, body=out_file)  
    
    return output_key

# %% [markdown]
# Combine previous split subsets:

# %%
fexec.map(gather_blocks, tiles, extra_args=(SPLITS, 'extrad'), runtime_memory=1024)

fexec.map(gather_blocks, tiles, extra_args=(SPLITS, 'humi'), runtime_memory=1024)

fexec.map(gather_blocks, tiles, extra_args=(SPLITS, 'rad'), runtime_memory=1024)

fexec.map(gather_blocks, tiles, extra_args=(SPLITS, 'temp'), runtime_memory=1024)

fexec.map(gather_blocks, tiles, extra_args=(SPLITS, 'wind'), runtime_memory=1024)

out_combined = fexec.get_result()
# Out:
# 2021-09-21 22:48:20,119 [INFO] lithops.invokers -- ExecutorID dd8057-0 | JobID M004 - Selected Runtime: jsampe/lithops-ibmcf-geospatial-v38:06 - 1024MB
# 2021-09-21 22:48:20,120 [DEBUG] lithops.storage.storage -- Runtime metadata found in local memory cache
# 2021-09-21 22:48:20,121 [DEBUG] lithops.job.job -- ExecutorID dd8057-0 | JobID M004 - Serializing function and data
# 2021-09-21 22:48:20,126 [DEBUG] lithops.job.serialize -- Referenced modules: /usr/local/lib/python3.8/dist-packages/rasterio/__init__.py, /usr/lib/python3.8/os.py, /usr/local/lib/python3.8/dist-packages/rasterio/windows.py, math
# 2021-09-21 22:48:20,131 [DEBUG] lithops.job.serialize -- Modules to transmit: None
# 2021-09-21 22:48:20,132 [DEBUG] lithops.job.job -- ExecutorID dd8057-0 | JobID M004 - Uploading function and modules to the storage backend
# 2021-09-21 22:48:20,411 [DEBUG] lithops.storage.backends.ibm_cos.ibm_cos -- PUT Object lithops.jobs/dd8057-0/307abea834b66d449e9d45b05cbfd080.func.pickle - Size: 1.6KiB - OK
# 2021-09-21 22:48:20,413 [DEBUG] lithops.job.job -- ExecutorID dd8057-0 | JobID M004 - Data per activation is < 8.0KiB. Passing data through invocation payload
# 2021-09-21 22:48:20,414 [INFO] lithops.invokers -- ExecutorID dd8057-0 | JobID M004 - Starting function invocation: gather_blocks() - Total: 8 activations
# 2021-09-21 22:48:20,419 [DEBUG] lithops.invokers -- ExecutorID dd8057-0 | JobID M004 - Chunksize: 1 - Worker processes: 1
# 2021-09-21 22:48:20,419 [DEBUG] lithops.invokers -- ExecutorID dd8057-0 | JobID M004 - Free workers: 912 - Going to run 8 activations in 8 workers
# 2021-09-21 22:48:20,420 [INFO] lithops.invokers -- ExecutorID dd8057-0 | JobID M004 - View execution logs at /tmp/lithops/logs/dd8057-0-M004.log
# 2021-09-21 22:48:20,437 [DEBUG] lithops.monitor -- ExecutorID dd8057-0 - Starting Storage job monitor
# 2021-09-21 22:48:20,437 [INFO] lithops.invokers -- ExecutorID dd8057-0 | JobID M005 - Selected Runtime: jsampe/lithops-ibmcf-geospatial-v38:06 - 1024MB
# 2021-09-21 22:48:20,439 [DEBUG] lithops.storage.storage -- Runtime metadata found in local memory cache
# 2021-09-21 22:48:20,439 [DEBUG] lithops.job.job -- ExecutorID dd8057-0 | JobID M005 - Serializing function and data
# 2021-09-21 22:48:20,443 [DEBUG] lithops.job.serialize -- Referenced modules: /usr/local/lib/python3.8/dist-packages/rasterio/__init__.py, /usr/lib/python3.8/os.py, /usr/local/lib/python3.8/dist-packages/rasterio/windows.py, math
# 2021-09-21 22:48:20,444 [DEBUG] lithops.job.serialize -- Modules to transmit: None
# 2021-09-21 22:48:20,445 [DEBUG] lithops.job.job -- ExecutorID dd8057-0 | JobID M005 - Function and modules found in local cache
# 2021-09-21 22:48:20,445 [DEBUG] lithops.job.job -- ExecutorID dd8057-0 | JobID M005 - Data per activation is < 8.0KiB. Passing data through invocation payload
# 2021-09-21 22:48:20,446 [INFO] lithops.invokers -- ExecutorID dd8057-0 | JobID M005 - Starting function invocation: gather_blocks() - Total: 8 activations
# 2021-09-21 22:48:20,446 [DEBUG] lithops.invokers -- ExecutorID dd8057-0 | JobID M005 - Chunksize: 1 - Worker processes: 1
# 2021-09-21 22:48:20,447 [DEBUG] lithops.invokers -- ExecutorID dd8057-0 | JobID M005 - Free workers: 904 - Going to run 8 activations in 8 workers
# 2021-09-21 22:48:20,448 [INFO] lithops.invokers -- ExecutorID dd8057-0 | JobID M005 - View execution logs at /tmp/lithops/logs/dd8057-0-M005.log
# 2021-09-21 22:48:20,453 [INFO] lithops.invokers -- ExecutorID dd8057-0 | JobID M006 - Selected Runtime: jsampe/lithops-ibmcf-geospatial-v38:06 - 1024MB
# 2021-09-21 22:48:20,455 [DEBUG] lithops.storage.storage -- Runtime metadata found in local memory cache
# 2021-09-21 22:48:20,455 [DEBUG] lithops.job.job -- ExecutorID dd8057-0 | JobID M006 - Serializing function and data
# 2021-09-21 22:48:20,460 [DEBUG] lithops.job.serialize -- Referenced modules: /usr/local/lib/python3.8/dist-packages/rasterio/__init__.py, /usr/lib/python3.8/os.py, /usr/local/lib/python3.8/dist-packages/rasterio/windows.py, math
# 2021-09-21 22:48:20,461 [DEBUG] lithops.job.serialize -- Modules to transmit: None
# 2021-09-21 22:48:20,461 [DEBUG] lithops.job.job -- ExecutorID dd8057-0 | JobID M006 - Function and modules found in local cache
# 2021-09-21 22:48:20,462 [DEBUG] lithops.job.job -- ExecutorID dd8057-0 | JobID M006 - Data per activation is < 8.0KiB. Passing data through invocation payload
# 2021-09-21 22:48:20,462 [INFO] lithops.invokers -- ExecutorID dd8057-0 | JobID M006 - Starting function invocation: gather_blocks() - Total: 8 activations
# 2021-09-21 22:48:20,464 [DEBUG] lithops.invokers -- ExecutorID dd8057-0 | JobID M006 - Chunksize: 1 - Worker processes: 1
# 2021-09-21 22:48:20,465 [DEBUG] lithops.invokers -- ExecutorID dd8057-0 | JobID M006 - Free workers: 896 - Going to run 8 activations in 8 workers
# 2021-09-21 22:48:20,466 [INFO] lithops.invokers -- ExecutorID dd8057-0 | JobID M006 - View execution logs at /tmp/lithops/logs/dd8057-0-M006.log
# 2021-09-21 22:48:20,479 [INFO] lithops.invokers -- ExecutorID dd8057-0 | JobID M007 - Selected Runtime: jsampe/lithops-ibmcf-geospatial-v38:06 - 1024MB
# 2021-09-21 22:48:20,480 [DEBUG] lithops.storage.storage -- Runtime metadata found in local memory cache
# 2021-09-21 22:48:20,481 [DEBUG] lithops.job.job -- ExecutorID dd8057-0 | JobID M007 - Serializing function and data
# 2021-09-21 22:48:20,485 [DEBUG] lithops.job.serialize -- Referenced modules: /usr/local/lib/python3.8/dist-packages/rasterio/__init__.py, /usr/lib/python3.8/os.py, /usr/local/lib/python3.8/dist-packages/rasterio/windows.py, math
# 2021-09-21 22:48:20,486 [DEBUG] lithops.job.serialize -- Modules to transmit: None
# 2021-09-21 22:48:20,487 [DEBUG] lithops.job.job -- ExecutorID dd8057-0 | JobID M007 - Function and modules found in local cache
# 2021-09-21 22:48:20,488 [DEBUG] lithops.job.job -- ExecutorID dd8057-0 | JobID M007 - Data per activation is < 8.0KiB. Passing data through invocation payload
# 2021-09-21 22:48:20,488 [INFO] lithops.invokers -- ExecutorID dd8057-0 | JobID M007 - Starting function invocation: gather_blocks() - Total: 8 activations
# 2021-09-21 22:48:20,489 [DEBUG] lithops.invokers -- ExecutorID dd8057-0 | JobID M007 - Chunksize: 1 - Worker processes: 1
# 2021-09-21 22:48:20,489 [DEBUG] lithops.invokers -- ExecutorID dd8057-0 | JobID M007 - Free workers: 888 - Going to run 8 activations in 8 workers
# 2021-09-21 22:48:20,490 [INFO] lithops.invokers -- ExecutorID dd8057-0 | JobID M007 - View execution logs at /tmp/lithops/logs/dd8057-0-M007.log
# 2021-09-21 22:48:20,495 [INFO] lithops.invokers -- ExecutorID dd8057-0 | JobID M008 - Selected Runtime: jsampe/lithops-ibmcf-geospatial-v38:06 - 1024MB
# 2021-09-21 22:48:20,497 [DEBUG] lithops.storage.storage -- Runtime metadata found in local memory cache
# 2021-09-21 22:48:20,498 [DEBUG] lithops.job.job -- ExecutorID dd8057-0 | JobID M008 - Serializing function and data
# 2021-09-21 22:48:20,502 [DEBUG] lithops.job.serialize -- Referenced modules: /usr/local/lib/python3.8/dist-packages/rasterio/__init__.py, /usr/lib/python3.8/os.py, /usr/local/lib/python3.8/dist-packages/rasterio/windows.py, math
# 2021-09-21 22:48:20,506 [DEBUG] lithops.job.serialize -- Modules to transmit: None
# 2021-09-21 22:48:20,508 [DEBUG] lithops.job.job -- ExecutorID dd8057-0 | JobID M008 - Function and modules found in local cache
# 2021-09-21 22:48:20,509 [DEBUG] lithops.job.job -- ExecutorID dd8057-0 | JobID M008 - Data per activation is < 8.0KiB. Passing data through invocation payload
# 2021-09-21 22:48:20,509 [INFO] lithops.invokers -- ExecutorID dd8057-0 | JobID M008 - Starting function invocation: gather_blocks() - Total: 8 activations
# 2021-09-21 22:48:20,510 [DEBUG] lithops.invokers -- ExecutorID dd8057-0 | JobID M008 - Chunksize: 1 - Worker processes: 1
# 2021-09-21 22:48:20,511 [DEBUG] lithops.invokers -- ExecutorID dd8057-0 | JobID M008 - Free workers: 880 - Going to run 8 activations in 8 workers
# 2021-09-21 22:48:20,511 [INFO] lithops.invokers -- ExecutorID dd8057-0 | JobID M008 - View execution logs at /tmp/lithops/logs/dd8057-0-M008.log
# 2021-09-21 22:48:20,519 [INFO] lithops.wait -- ExecutorID dd8057-0 - Getting results from functions
# 2021-09-21 22:48:20,916 [DEBUG] lithops.invokers -- ExecutorID dd8057-0 | JobID M004 - Calls 00006 invoked (0.487s) - Activation ID: 2e3d37cccfef4026bd37cccfef802660
# 2021-09-21 22:48:20,919 [DEBUG] lithops.invokers -- ExecutorID dd8057-0 | JobID M004 - Calls 00005 invoked (0.491s) - Activation ID: 8376f98edba44b42b6f98edba4cb429c
# 2021-09-21 22:48:20,922 [DEBUG] lithops.invokers -- ExecutorID dd8057-0 | JobID M004 - Calls 00004 invoked (0.495s) - Activation ID: 5e15745ef78f477e95745ef78f177e2b
# 2021-09-21 22:48:20,926 [DEBUG] lithops.invokers -- ExecutorID dd8057-0 | JobID M004 - Calls 00000 invoked (0.505s) - Activation ID: 37470ee9cbbd48f7870ee9cbbde8f73e
# 2021-09-21 22:48:20,928 [DEBUG] lithops.invokers -- ExecutorID dd8057-0 | JobID M004 - Calls 
[DEBUG] lithops.future -- ExecutorID dd8057-0 | JobID M007 - Got output from call 00007 - Activation ID: 96aa7f0e340547a8aa7f0e340577a86d
# 2021-09-21 22:49:11,677 [DEBUG] lithops.future -- ExecutorID dd8057-0 | JobID M007 - Got output from call 00003 - Activation ID: d19ac8d060b94b129ac8d060b93b1252
# 2021-09-21 22:49:11,704 [DEBUG] lithops.future -- ExecutorID dd8057-0 | JobID M007 - Got output from call 00004 - Activation ID: e34e52956fc947bc8e52956fc9f7bc90
# 2021-09-21 22:49:11,707 [INFO] lithops.executors -- ExecutorID dd8057-0 - Cleaning temporary data
# 2021-09-21 22:49:11,721 [DEBUG] lithops.executors -- ExecutorID dd8057-0 - Finished getting results

# %% [markdown]
# ## Computation of potential evaporation

# %%
def compute_crop_evapotranspiration(temperatures,
                                    humidities,
                                    wind_speeds,
                                    external_radiations,
                                    global_radiations,
                                    KCs):
    gamma = 0.665*101.3/1000
    eSat = 0.6108 * np.exp((17.27*temperatures)/(temperatures+237.3))
    delta = 4098 * eSat / np.power((temperatures + 237.3),2)
    eA = np.where(humidities < 0, 0, eSat * humidities / 100)     # Avoid sqrt of a negative number
    T4 = 4.903 * np.power((273.3 + temperatures),4)/1000000000
    rSrS0 = global_radiations/(external_radiations * 0.75)
    rN = 0.8* global_radiations-T4*(0.34-0.14*np.sqrt(eA))*((1.35*rSrS0)-0.35)
    den = delta + gamma *(1 + 0.34* wind_speeds)
    tRad = 0.408 * delta * rN / den
    tAdv = gamma * (900/(temperatures+273))*wind_speeds * (eSat - eA)/den
    return ((tRad + tAdv) * 7 * KCs).astype('float32')

# %%
vineyard = ['VI', 'VO', 'VF', 'FV', 'CV' ]
olive_grove = ['OV', 'VO', 'OF', 'FL', 'OC']
fruit = ['FY', 'VF', 'OF', 'FF', 'CF']
nuts = ['FS', 'FV', 'FL', 'FF', 'CS' ]
citrus = ['CI', 'CV', 'OC', 'CF', 'CS' ]

def get_kc(feature):
    
    # TODO: Get more precise values of Kc
    sigpac_use = feature['properties']['uso_sigpac']
    if sigpac_use in vineyard:
        # Grapes for wine - 0.3, 0.7, 0.45
        return 0.7  
    if sigpac_use in olive_grove:
        # Olive grove - ini: 0.65, med: 0.7, end: 0.7
        return 0.7 
    if sigpac_use in fruit:
        # Apples, Cherries, Pears - 0.45, 0.95, 0.7
        return 0.95
    if sigpac_use in nuts:
        # Almonds - 0.4, 0.9, 0.65
        return 0.9
    if sigpac_use in citrus:
        # Citrus, without ground coverage - 0.7, 0.65, 0.7
        return 0.65
    
    return None

# %%
def get_geometry_window(src, geom_bounds):
    left, bottom, right, top = geom_bounds
    src_left, src_bottom, src_right, src_top = src.bounds
    window = src.window(max(left,src_left), max(bottom,src_bottom), min(right,src_right), min(top,src_top))
    window_floored = window.round_offsets(op='floor', pixel_precision=3)
    w = math.ceil(window.width + window.col_off - window_floored.col_off)
    h = math.ceil(window.height + window.row_off - window_floored.row_off)
    return Window(window_floored.col_off, window_floored.row_off, w, h)

# %%
def compute_evapotranspiration_by_shape(tem, hum, win, rad, extrad, dst):
    
    import fiona
    from shapely.geometry import shape, box
    from rasterio import features
    
    non_arable_land = ['AG', 'CA', 'ED', 'FO', 'IM', 'PA', 'PR', 'ZU', 'ZV']
    
    with fiona.open('zip://shape.zip') as shape_src:
        for feature in shape_src.filter(bbox=tem.bounds):
            KC = get_kc(feature) 
            if KC is not None:   
                geom = shape(feature['geometry'])  
                window = get_geometry_window(tem, geom.bounds)              
                win_transform = rasterio.windows.transform(window, tem.transform)
                # Convert shape to raster matrix
                image = features.rasterize([geom],
                                           out_shape=(window.height, window.width),
                                           transform = win_transform,
                                           fill = 0,
                                           default_value = 1).astype('bool')
                # Get values to compute evapotranspiration
                temperatures = tem.read(1, window=window)
                humidities = hum.read(1, window=window)
                wind_speeds = win.read(1, window=window)
                # Convert from W to MJ (0.0036)
                global_radiations = rad.read(1, window=window) * 0.0036
                external_radiations = extrad.read(1, window=window) * 0.0036
                KCs = np.full(temperatures.shape, KC)
                # TODO: compute external radiation
                #external_radiations = np.full(temperatures.shape, 14)
                # TODO: compute global radiation
                # global_radiations = np.full(temperatures.shape, 10)
                etc = compute_crop_evapotranspiration(
                        temperatures,
                        humidities,
                        wind_speeds,
                        external_radiations,
                        global_radiations,
                        KCs
                )
                etc[temperatures == tem.nodata] = dst.nodata
                etc[np.logical_not(image)] = dst.nodata
                dst.write(etc + dst.read(1, window=window), 1, window=window)

# %%
def compute_global_evapotranspiration(tem, hum, win, rad, extrad, dst):    
    for ji, window in tem.block_windows(1):
        bounds = rasterio.windows.bounds(window, tem.transform)
        temperatures = tem.read(1, window=window)
        humidities = hum.read(1, window=window)
        wind_speeds = win.read(1, window=window)
         # Convert from W to MJ (0.0036)
        global_radiations = rad.read(1, window=window) * 0.0036
        external_radiations = extrad.read(1, window=window) * 0.0036
        # TODO: compute external radiation
        #external_radiations = np.full(temperatures.shape, 14)
        # TODO: compute global radiation
        # global_radiations = np.full(temperatures.shape, 10)
        # TODO: compute KCs
        KCs = np.full(temperatures.shape, 1)
        etc = compute_crop_evapotranspiration(
                temperatures,
                humidities,
                wind_speeds,
                external_radiations,
                global_radiations,
                KCs
        )
        dst.write(np.where(temperatures == tem.nodata, dst.nodata, etc), 1, window=window)

# %%
def combine_calculations(tile, storage):      
    # Download shapefile
    shapefile = storage.get_object(bucket=BUCKET, key='shapefile.zip', stream=True)
    with open('shape.zip', 'wb') as shapf:
        for chunk in iter(partial(shapefile.read, 200 * 1024 * 1024), ''):
            if not chunk:
                break
            shapf.write(chunk)
    
    temp = storage.get_object(bucket=BUCKET, key=f'tmp/temp/{tile}/{tile}_TEMP.tif', stream=True)
    humi = storage.get_object(bucket=BUCKET, key=f'tmp/humi/{tile}/{tile}_HUMI.tif', stream=True)
    rad = storage.get_object(bucket=BUCKET, key=f'tmp/rad/{tile}/{tile}_RAD.tif', stream=True)
    extrad = storage.get_object(bucket=BUCKET, key=f'tmp/extrad/{tile}/{tile}_EXTRAD.tif', stream=True)
    wind = storage.get_object(bucket=BUCKET, key=f'tmp/wind/{tile}/{tile}_WIND.tif', stream=True)
    
    with rasterio.open(temp) as temp_raster:
        with rasterio.open(humi) as humi_raster:
            with rasterio.open(rad) as rad_raster:
                with rasterio.open(extrad) as extrad_raster:
                    with rasterio.open(wind) as wind_raster:
                        profile = temp_raster.profile
                        profile.update(nodata=0)
        
                        with rasterio.open('output', 'w+', **profile) as dst:
#                             compute_global_evapotranspiration(temp_raster, humi_raster, wind_raster,
#                                                               rad_raster, extrad_raster, dst)
                            compute_evapotranspiration_by_shape(temp_raster, humi_raster, wind_raster,
                                                                rad_raster, extrad_raster, dst)
    
    out_key = f'etc/{tile}_ETC.tif'
    with open('output', 'rb') as output_f:
        storage.put_object(bucket=BUCKET, key=out_key, body=output_f)
    return out_key

# %%
fexec.map(combine_calculations, tiles, runtime_memory=2048)

res = fexec.get_result()
# Out:
# 2021-09-21 22:49:12,369 [INFO] lithops.invokers -- ExecutorID dd8057-0 | JobID M009 - Selected Runtime: jsampe/lithops-ibmcf-geospatial-v38:06 - 2048MB
# 2021-09-21 22:49:12,371 [DEBUG] lithops.storage.storage -- Runtime metadata found in local disk cache
# 2021-09-21 22:49:12,372 [DEBUG] lithops.job.job -- ExecutorID dd8057-0 | JobID M009 - Serializing function and data
# 2021-09-21 22:49:12,384 [DEBUG] lithops.job.serialize -- Referenced modules: /usr/local/lib/python3.8/dist-packages/rasterio/__init__.py, /usr/local/lib/python3.8/dist-packages/shapely/geometry/geo.py, /usr/local/lib/python3.8/dist-packages/shapely/geometry/polygon.py, /home/josep/.local/lib/python3.8/site-packages/numpy/__init__.py, /usr/local/lib/python3.8/dist-packages/shapely/__init__.py, /usr/lib/python3.8/functools.py, /usr/local/lib/python3.8/dist-packages/shapely/geometry/__init__.py, math, /usr/local/lib/python3.8/dist-packages/rasterio/windows.py
# 2021-09-21 22:49:12,384 [DEBUG] lithops.job.serialize -- Modules to transmit: None
# 2021-09-21 22:49:12,387 [DEBUG] lithops.job.job -- ExecutorID dd8057-0 | JobID M009 - Uploading function and modules to the storage backend
# 2021-09-21 22:49:12,690 [DEBUG] lithops.storage.backends.ibm_cos.ibm_cos -- PUT Object lithops.jobs/dd8057-0/09de767a3f00ac9beb87ee9350e51641.func.pickle - Size: 4.6KiB - OK
# 2021-09-21 22:49:12,691 [DEBUG] lithops.job.job -- ExecutorID dd8057-0 | JobID M009 - Data per activation is < 8.0KiB. Passing data through invocation payload
# 2021-09-21 22:49:12,692 [INFO] lithops.invokers -- ExecutorID dd8057-0 | JobID M009 - Starting function invocation: combine_calculations() - Total: 8 activations
# 2021-09-21 22:49:12,693 [DEBUG] lithops.invokers -- ExecutorID dd8057-0 | JobID M009 - Chunksize: 1 - Worker processes: 1
# 2021-09-21 22:49:12,694 [DEBUG] lithops.invokers -- ExecutorID dd8057-0 | JobID M009 - Free workers: 872 - Going to run 8 activations in 8 workers
# 2021-09-21 22:49:12,695 [INFO] lithops.invokers -- ExecutorID dd8057-0 | JobID M009 - View execution logs at /tmp/lithops/logs/dd8057-0-M009.log
# 2021-09-21 22:49:12,704 [DEBUG] lithops.monitor -- ExecutorID dd8057-0 - Starting Storage job monitor
# 2021-09-21 22:49:12,704 [INFO] lithops.wait -- ExecutorID dd8057-0 - Getting results from functions
# 2021-09-21 22:49:13,204 [DEBUG] lithops.invokers -- ExecutorID dd8057-0 | JobID M009 - Calls 00005 invoked (0.505s) - Activation ID: a5ec2361d01b4c6bac2361d01b6c6bed
# 2021-09-21 22:49:13,205 [DEBUG] lithops.invokers -- ExecutorID dd8057-0 | JobID M009 - Calls 00006 invoked (0.506s) - Activation ID: db3dd3b36c994317bdd3b36c993317d8
# 2021-09-21 22:49:13,216 [DEBUG] lithops.invokers -- ExecutorID dd8057-0 | JobID M009 - Calls 00000 invoked (0.520s) - Activation ID: f84f7004efee492b8f7004efee892b8b
# 2021-09-21 22:49:13,217 [DEBUG] lithops.invokers -- ExecutorID dd8057-0 | JobID M009 - Calls 00004 invoked (0.519s) - Activation ID: 0e212e82f9ce4850a12e82f9ce485026
# 2021-09-21 22:49:13,230 [DEBUG] lithops.invokers -- ExecutorID dd8057-0 | JobID M009 - Calls 00002 invoked (0.534s) - Activation ID: 9e9a3e95f16c453b9a3e95f16c453b5f
# 2021-09-21 22:49:13,231 [DEBUG] lithops.invokers -- ExecutorID dd8057-0 | JobID M009 - Calls 00007 invoked (0.531s) - Activation ID: 3ae0c646ac3649a7a0c646ac3619a7f3
# 2021-09-21 22:49:13,232 [DEBUG] lithops.invokers -- ExecutorID dd8057-0 | JobID M009 - Calls 00001 invoked (0.536s) - Activation ID: a3727c1011a54ac2b27c1011a5eac233
# 2021-09-21 22:49:13,232 [DEBUG] lithops.invokers -- ExecutorID dd8057-0 | JobID M009 - Calls 00003 invoked (0.534s) - Activation ID: b417713a355742cb97713a355732cb7e
# 2021-09-21 22:49:15,024 [DEBUG] lithops.monitor -- ExecutorID dd8057-0 - Pending: 3 - Running: 5 - Done: 0
# 2021-09-21 22:49:17,375 [DEBUG] lithops.monitor -- ExecutorID dd8057-0 - Pending: 2 - Running: 1 - Done: 5
# 2021-09-21 22:49:17,720 [DEBUG] lithops.invokers -- ExecutorID dd8057-0 - Stopping async invokers
# 2021-09-21 22:49:17,723 [DEBUG] lithops.invokers -- ExecutorID dd8057-0 - Async invoker 0 finished
# 2021-09-21 22:49:17,723 [DEBUG] lithops.invokers -- ExecutorID dd8057-0 - Async invoker 1 finished
# 2021-09-21 22:49:17,885 [DEBUG] lithops.monitor -- ExecutorID dd8057-0 - Storage job monitor finished
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2464337/1235337338.py in <module>
#       1 fexec.map(combine_calculations, tiles, runtime_memory=2048)
#       2
# ----> 3 res = fexec.get_result()
#
# ~/data/dev-workspace/lithops/lithops/lithops/executors.py in get_result(self, fs, throw_except, timeout, threadpool_size, wait_dur_sec)
#     463         :return: The result of the future/s
#     464         """
# --> 465         fs_done, _ = self.wait(fs=fs, throw_except=throw_except,
#     466                                timeout=timeout, download_results=True,
#     467                                threadpool_size=threadpool_size,
#
# ~/data/dev-workspace/lithops/lithops/lithops/executors.py in wait(self, fs, throw_except, return_when, download_results, timeout, threadpool_size, wait_dur_sec)
#     430             if self.data_cleaner and not self.is_lithops_worker:
#     431                 self.clean(clean_cloudobjects=False, force=True)
# --> 432             raise e
#     433
#     434         finally:
#
# ~/data/dev-workspace/lithops/lithops/lithops/executors.py in wait(self, fs, throw_except, return_when, download_results, timeout, threadpool_size, wait_dur_sec)
#     413         # Start waiting for results
#     414         try:
# --> 415             wait(fs=futures,
#     416                  internal_storage=self.internal_storage,
#     417                  job_monitor=self.job_monitor,
#
# ~/data/dev-workspace/lithops/lithops/lithops/wait.py in wait(fs, internal_storage, throw_except, timeout, return_when, download_results, job_monitor, threadpool_size, wait_dur_sec)
#     150
#     151     except Exception as e:
# --> 152         raise e
#     153
#     154     finally:
#
# ~/data/dev-workspace/lithops/lithops/lithops/wait.py in wait(fs, internal_storage, throw_except, timeout, return_when, download_results, job_monitor, threadpool_size, wait_dur_sec)
#     115             while not _all_done(fs, download_results):
#     116                 for executor_data in executors_data:
# --> 117                     new_data = _get_executor_data(fs, executor_data, pbar=pbar,
#     118                                                   throw_except=throw_except,
#     119                                                   download_results=download_results,
#
# ~/data/dev-workspace/lithops/lithops/lithops/wait.py in _get_executor_data(fs, exec_data, download_results, throw_except, threadpool_size, pbar)
#     273     pool = cf.ThreadPoolExecutor(max_workers=threadpool_size)
#     274     if download_results:
# --> 275         list(pool.map(get_result, fs_to_wait_on))
#     276     else:
#     277         list(pool.map(get_status, fs_to_wait_on))
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result_iterator()
#     617                     # Careful not to keep a reference to the popped future
#     618                     if timeout is None:
# --> 619                         yield fs.pop().result()
#     620                     else:
#     621                         yield fs.pop().result(end_time - time.monotonic())
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     442                     raise CancelledError()
#     443                 elif self._state == FINISHED:
# --> 444                     return self.__get_result()
#     445                 else:
#     446                     raise TimeoutError()
#
# /usr/lib/python3.8/concurrent/futures/_base.py in __get_result(self)
#     387         if self._exception:
#     388             try:
# --> 389                 raise self._exception
#     390             finally:
#     391                 # Break a reference cycle with the exception in self._exception
#
# /usr/lib/python3.8/concurrent/futures/thread.py in run(self)
#      55
#      56         try:
# ---> 57             result = self.fn(*self.args, **self.kwargs)
#      58         except BaseException as exc:
#      59             self.future.set_exception(exc)
#
# ~/data/dev-workspace/lithops/lithops/lithops/wait.py in get_result(f)
#     266
#     267     def get_result(f):
# --> 268         f.result(throw_except=throw_except, internal_storage=exec_data.internal_storage)
#     269
#     270     def get_status(f):
#
# ~/data/dev-workspace/lithops/lithops/lithops/future.py in result(self, throw_except, internal_storage)
#     319             internal_storage = InternalStorage(storage_config=self._storage_config)
#     320
# --> 321         self.status(throw_except=throw_except, internal_storage=internal_storage)
#     322
#     323         if self.done:
#
# ~/data/dev-workspace/lithops/lithops/lithops/future.py in status(self, throw_except, internal_storage, check_only)
#     254             if throw_except:
#     255                 sys.excepthook = exception_hook
# --> 256                 reraise(*self._exception)
#     257             else:
#     258                 logger.warning(msg1)
#
# /usr/lib/python3/dist-packages/six.py in reraise(tp, value, tb)
#     701             if value.__traceback__ is not tb:
#     702                 raise value.with_traceback(tb)
# --> 703             raise value
#     704         finally:
#     705             value = None
#
# /action/lithops/worker/jobrunner.py in run()
#
# /tmp/ipykernel_2464337/2481583679.py in combine_calculations()
#      25 #                             compute_global_evapotranspiration(temp_raster, humi_raster, wind_raster,
#      26 #                                                               rad_raster, extrad_raster, dst)
# ---> 27                             compute_evapotranspiration_by_shape(temp_raster, humi_raster, wind_raster,
#      28                                                                 rad_raster, extrad_raster, dst)
#      29
#
# /tmp/ipykernel_2464337/3405661654.py in compute_evapotranspiration_by_shape()
#       9     with fiona.open('zip://shape.zip') as shape_src:
#      10         for feature in shape_src.filter(bbox=tem.bounds):
# ---> 11             KC = get_kc(feature)
#      12             if KC is not None:
#      13                 geom = shape(feature['geometry'])
#
# /tmp/ipykernel_2464337/2693345452.py in get_kc()
#       8
#       9     # TODO: Get more precise values of Kc
# ---> 10     sigpac_use = feature['properties']['uso_sigpac']
#      11     if sigpac_use in vineyard:
#      12         # Grapes for wine - 0.3, 0.7, 0.45
#
# KeyError: 'uso_sigpac'

# %% [markdown]
# ## Visualization of results

# %%
import io
tile = random.choice(tiles)
obj = io.BytesIO(cloud_storage.get_object(bucket=BUCKET, key=f'etc/{tile}_ETC.tif'))

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots()

with rasterio.open(obj) as src:
    arr = src.read(1, out_shape=(src.height, src.width))
    ax.set_title(tile)
    img = ax.imshow(arr, cmap='Greens')
    fig.colorbar(img, shrink=0.5)

fig.set_size_inches(18.5, 10.5)
plt.show()

obj.seek(0)

# %% [markdown]
# ### Utility functions

# %% [markdown]
# Remove intermediate data

# %%
# keys = cloud_storage.list_keys(bucket=BUCKET, prefix='')
# keys

# %%
# for key in keys:
#     cloud_storage.delete_object(bucket=BUCKET, key=key)
