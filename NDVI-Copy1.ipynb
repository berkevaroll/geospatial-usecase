# %% [markdown]
# # NDVI Calculation

# %%
import fiona
import sentinelsat
import ipywidgets as widgets
import numpy as np
import os
import lithops
import random
import rasterio
import re
import tempfile
import zipfile
import subprocess
import glob
import json
from rio_cogeo import cogeo

from collections import defaultdict
from datetime import date
from fiona.io import ZipMemoryFile
from matplotlib import pyplot as plt
from rasterio.io import MemoryFile
from zipfile import ZipFile
from ipyleaflet import Map, basemaps, basemap_to_tiles
from lithops.storage import Storage

from geospatial_usecase.utils import notebook as notebook_utils
from geospatial_usecase.io_utils.ndvi import get_ndvi_params, ndvi_calculation, ndvi_tile_sentinel, get_subset_raster, lonlat_to_utm, get_poly_within
from geospatial_usecase.io_utils.plot import tiff_overview, plot_map

os.environ['CURL_CA_BUNDLE'] = '/etc/ssl/certs/ca-certificates.crt'

# %% [markdown]
# Set the environmental variables *SENTINEL_USERNAME* and *SENTINEL_PASSWORD* to match your Sentinel-2 credentials. You can register and access data for free at https://sentinel.esa.int/web/sentinel/sentinel-data-access/registration:

# %%
sentinel_product_dir = ""
cmd = ['L2A_Process --resolution 10 {}'.format(sentinel_product_dir)]
val = subprocess.check_output(cmd, stderr=subprocess.STDOUT, shell=True, universal_newlines=True)
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-48-968b8e0ceabc> in <module>
#       1 sentinel_product_dir = ""
#       2 cmd = ['L2A_Process --resolution 10 {}'.format(sentinel_product_dir)]
# ----> 3 val = subprocess.check_output(cmd, stderr=subprocess.STDOUT, shell=True, universal_newlines=True)
#
# /opt/conda/lib/python3.8/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     413         kwargs['input'] = empty
#     414
# --> 415     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     416                **kwargs).stdout
#     417
#
# /opt/conda/lib/python3.8/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     514         retcode = process.poll()
#     515         if check and retcode:
# --> 516             raise CalledProcessError(retcode, process.args,
#     517                                      output=stdout, stderr=stderr)
#     518     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['L2A_Process --resolution 10 ']' returned non-zero exit status 127.

# %%
SENTINEL_USERNAME = 'vmoreno'
SENTINEL_PASSWORD = '12345678'
STORAGE_BUCKET = 'geospatial-usecase'

# %%
# %matplotlib inline

# %%
cloud_storage = Storage(backend="ceph")
# Out:
# 2021-07-26 11:28:32,366 [DEBUG] lithops.config -- Loading configuration from /home/jovyan/work/.lithops_config
# 2021-07-26 11:28:32,381 [DEBUG] lithops.config -- Loading Storage backend module: ceph
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-45-a4136e1cf980> in <module>
# ----> 1 cloud_storage = Storage(backend="ceph")
#
# /opt/conda/lib/python3.8/site-packages/lithops/storage/storage.py in __init__(self, config, backend, storage_config)
#      49
#      50         if storage_config:
# ---> 51             self.storage_config = storage_config
#      52         else:
#      53             storage_config = default_storage_config(config_data=config,
#
# /opt/conda/lib/python3.8/site-packages/lithops/config.py in default_storage_config(config_data, backend)
#     262
#     263     if 'storage_bucket' not in config_data['lithops']:
# --> 264         raise Exception("storage_bucket is mandatory in "
#     265                         "lithops section of the configuration")
#     266
#
# /opt/conda/lib/python3.8/site-packages/lithops/storage/backends/ceph/config.py in load_config(config_data)
#      26         if param not in config_data['ceph']:
#      27             msg = f"'{param}' is mandatory under 'ceph' section of the configuration"
# ---> 28             raise Exception(msg)
#      29
#      30     if not config_data['ceph']['endpoint'].startswith('http'):
#
# Exception: 'secret_key' is mandatory under 'ceph' section of the configuration

# %% [markdown]
# ## Input parameters

# %% [markdown]
# Select the date interval in which tiles will be processed:

# %%
from_day, to_day = notebook_utils.pick_date_range()
# Out:
# DatePicker(value=datetime.date(2020, 12, 1), description='From day')
# DatePicker(value=datetime.date(2020, 12, 31), description='To day')

# %% [markdown]
# Select the tile's cloud percentage threshold:

# %%
percentage = notebook_utils.pick_percentage_slider()
# Out:
# IntSlider(value=15, continuous_update=False, description='Porcentaje de nubosidad')

# %% [markdown]
# Select the area which delimites the tiles you want to process (left click to mark a point in the map, right click to erase current selection):

# %%
# map_region = notebook_utils.MapRegion()

# %% [markdown]
# ## Get Sentinel-2 metadata

# %%
# locations = map_region.get_region()

# Tarragona data
locations = [[1.5481363013595886, 41.16508628430497],
 [0.8177319989996914, 40.62111912603713],
 [0.6008074129604647, 40.60652433834119],
 [0.4552757286556909, 40.868742532626996],
 [0.3811369460853299, 41.03883697553436],
 [0.427816920296289, 41.247740935856484],
 [0.694167361382423, 41.33441592882952],
 [1.097811844265526, 41.39831645175795],
 [1.452030472101722, 41.365343372983396],
 [1.5481363013595886, 41.16508628430497]]

# %%
geo_json_area = {
    "features": [
        {
            "geometry": {
                "coordinates":[locations],
                "type": "Polygon"
            },
            "properties": {},
            "type": "Feature"
        }
    ],
    "type": "FeatureCollection"
}

# %% [markdown]
# Using the selected parameters, get the identifiers of the selected tiles from Sentinel-2:

# %%
sentinel_api = sentinelsat.SentinelAPI(user=SENTINEL_USERNAME,
                                       password=SENTINEL_PASSWORD,
                                      api_url="https://apihub.copernicus.eu/apihub/")
footprint = sentinelsat.geojson_to_wkt(geo_json_area)
products = sentinel_api.query(footprint,
                              date=(from_day.value, to_day.value),
                              platformname='Sentinel-2',
                              producttype=('S2MS2Ap', 'S2MSI1C'),
                              cloudcoverpercentage=(0, percentage.value))
geojson_products = sentinel_api.to_geojson(products)

# %%
# debug
# geojson_products = [geojson_products[0]]

# %%
print('Number of tiles: {}'.format(len(geojson_products)))
# Out:
# Number of tiles: 2

# %%
print(geojson_products)
print(type(geojson_products["features"]))
# Out:
# {"features": [{"geometry": {"coordinates": [[[[0.366495, 39.630196], [0.783235, 39.640449], [0.750865, 40.628949], [0.667839, 40.626864], [0.652362, 40.576078], [0.607722, 40.428958], [0.563076, 40.281801], [0.51852, 40.134544], [0.474079, 39.987268], [0.429623, 39.839979], [0.385189, 39.692698], [0.366495, 39.630196]]]], "type": "MultiPolygon"}, "id": 0, "properties": {"beginposition": "2020-12-28T10:43:49.024000Z", "cloudcoverpercentage": 0.0, "datastripidentifier": "S2B_OPER_MSI_L1C_DS_EPAE_20201228T113546_S20201228T104344_N02.09", "datatakesensingstart": "2020-12-28T10:43:49.024000Z", "endposition": "2020-12-28T10:43:49.024000Z", "filename": "S2B_MSIL1C_20201228T104349_N0209_R008_T31TBE_20201228T113546.SAFE", "format": "SAFE", "granuleidentifier": "S2B_OPER_MSI_L1C_TL_EPAE_20201228T113546_A019911_T31TBE_N02.09", "hv_order_tileid": "TE31B", "id": "9368bf63-3e92-4cea-817f-bdd8f860b911", "identifier": "S2B_MSIL1C_20201228T104349_N0209_R008_T31TBE_20201228T113546", "ingestiondate": "2020-12-28T13:17:01.816000Z", "instrumentname": "Multi-Spectral Instrument", "instrumentshortname": "MSI", "level1cpdiidentifier": "S2B_OPER_MSI_L1C_TL_EPAE_20201228T113546_A019911_T31TBE_N02.09", "link": "https://apihub.copernicus.eu/apihub/odata/v1/Products('9368bf63-3e92-4cea-817f-bdd8f860b911')/$value", "link_alternative": "https://apihub.copernicus.eu/apihub/odata/v1/Products('9368bf63-3e92-4cea-817f-bdd8f860b911')/", "link_icon": "https://apihub.copernicus.eu/apihub/odata/v1/Products('9368bf63-3e92-4cea-817f-bdd8f860b911')/Products('Quicklook')/$value", "ondemand": "false", "orbitdirection": "DESCENDING", "orbitnumber": 19911, "platformidentifier": "2017-013A", "platformname": "Sentinel-2", "platformserialidentifier": "Sentinel-2B", "processingbaseline": "02.09", "processinglevel": "Level-1C", "producttype": "S2MSI1C", "relativeorbitnumber": 8, "s2datatakeid": "GS2B_20201228T104349_019911_N02.09", "sensoroperationalmode": "INS-NOBS", "size": "127.83 MB", "summary": "Date: 2020-12-28T10:43:49.024Z, Instrument: MSI, Satellite: Sentinel-2, Size: 127.83 MB", "tileid": "31TBE", "title": "S2B_MSIL1C_20201228T104349_N0209_R008_T31TBE_20201228T113546", "uuid": "9368bf63-3e92-4cea-817f-bdd8f860b911"}, "type": "Feature"}, {"geometry": {"coordinates": [[[[0.669349, 39.638218], [1.948551, 39.656847], [1.933185, 40.645928], [0.667918, 40.627124], [0.652362, 40.576078], [0.638619, 40.530786], [0.669349, 39.638218]]]], "type": "MultiPolygon"}, "id": 1, "properties": {"beginposition": "2020-12-28T10:43:49.024000Z", "cloudcoverpercentage": 8.7122, "datastripidentifier": "S2B_OPER_MSI_L1C_DS_EPAE_20201228T113546_S20201228T104344_N02.09", "datatakesensingstart": "2020-12-28T10:43:49.024000Z", "endposition": "2020-12-28T10:43:49.024000Z", "filename": "S2B_MSIL1C_20201228T104349_N0209_R008_T31TCE_20201228T113546.SAFE", "format": "SAFE", "granuleidentifier": "S2B_OPER_MSI_L1C_TL_EPAE_20201228T113546_A019911_T31TCE_N02.09", "hv_order_tileid": "TE31C", "id": "191ba398-ade5-4aa9-a39a-163a3dbe9d4e", "identifier": "S2B_MSIL1C_20201228T104349_N0209_R008_T31TCE_20201228T113546", "ingestiondate": "2020-12-28T13:17:00.077000Z", "instrumentname": "Multi-Spectral Instrument", "instrumentshortname": "MSI", "level1cpdiidentifier": "S2B_OPER_MSI_L1C_TL_EPAE_20201228T113546_A019911_T31TCE_N02.09", "link": "https://apihub.copernicus.eu/apihub/odata/v1/Products('191ba398-ade5-4aa9-a39a-163a3dbe9d4e')/$value", "link_alternative": "https://apihub.copernicus.eu/apihub/odata/v1/Products('191ba398-ade5-4aa9-a39a-163a3dbe9d4e')/", "link_icon": "https://apihub.copernicus.eu/apihub/odata/v1/Products('191ba398-ade5-4aa9-a39a-163a3dbe9d4e')/Products('Quicklook')/$value", "ondemand": "false", "orbitdirection": "DESCENDING", "orbitnumber": 19911, "platformidentifier": "2017-013A", "platformname": "Sentinel-2", "platformserialidentifier": "Sentinel-2B", "processingbaseline": "02.09", "processinglevel": "Level-1C", "producttype": "S2MSI1C", "relativeorbitnumber": 8, "s2datatakeid": "GS2B_202012 ...
# <class 'list'>

# %% [markdown]
# ## Athmospheric correction using Serverful Lithops

# %% [markdown]
# Here we will download tile images from Sentinel2 using the previously selected configuration and apply athmospheric correction.
#
# This process is not parallelizable and lasts for over 20 minutes, so it is not suited for serverless functions. We will use Lithops Standalone instead, which uses serverful instances that haven't time limits.
#
# The runtime used packs Sentinel2 software and IBM Cloud Functions Python3.7 handler in a Dockerfile located in `sentinel2_runtime/Dockerfile`.

# %%
def jp2_to_cog(band_src_path):
    """
    Transform a sentinel2 band (.jp2) to GeoTiff (.tif)
    """
    config = dict(NUM_THREADS=100, GDAL_TIFF_OVR_BLOCKSIZE=128)

    output_profile = {
        "driver": "GTiff",
        "interleave": "pixel",
        "tiled": True,
        "blockxsize": 256,
        "blockysize": 256,
        "compress": "DEFLATE",
    }

    cog_path = f"{band_src_path[band_src_path.rfind('/')+1:band_src_path.rfind('.')]}.tif"
    cogeo.cog_translate(
        band_src_path,
        cog_path,
        output_profile,
        nodata=0,
        in_memory=False,
        config=config,
        quiet=True,
    )

    return cog_path

# %%
def perform_atmospheric_correction(product_geojson, storage):
    product = product_geojson['properties']
    tile = product['filename'][39:44]
    date = product['filename'][11:19]

    # Check if tile is already processed stored in COS, return if it is
    #keys = storage.list_keys(bucket=STORAGE_BUCKET)
    keys = []
    pattern = r".*" + re.escape(date) + r".*" + re.escape(tile) + r".*\.geojson"
    filtered = [file for file in keys if re.search(pattern, file)]
    if filtered:
        print('Tile already in COS: {}'.format(filtered))
        remote_geotiff = filtered.pop()
        return remote_geotiff

    # Download Sentinel-2 tile
    sentinel_api = sentinelsat.SentinelAPI(user=os.environ["SENTINEL_USERNAME"],
                                           password=os.environ["SENTINEL_PASSWORD"],
                                          api_url="https://apihub.copernicus.eu/apihub/")

    sentinel_product_dir = product['filename']
    tmpdir = tempfile.gettempdir()
    d_meta = sentinel_api.download(product['uuid'], directory_path=tmpdir)
    
    if d_meta['downloaded_bytes'] == 0:
        raise Exception(d_meta)
    
    # Extract and remove zip file
    zip_ref = zipfile.ZipFile(d_meta['path'])
    zip_ref.extractall(tmpdir)
    zip_ref.close()
    #os.remove(d_meta['path'])

    # Atmospheric correction
    sentinel_product_dir = os.path.join(tmpdir, product['filename'])
    corrected_images = glob.glob(f"*2A_{date}*_T{tile}_*.SAFE/GRANULE/*/IMG_DATA/R10m/*B0[48]*.jp2")
    atmospheric_corrected = corrected_images[0] if len(corrected_images) > 0 else None

    if not atmospheric_corrected:
        print(f'Doing the atmospheric correction for {sentinel_product_dir}')
        try:
            cmd = ['L2A_Process --resolution 10 {}'.format(sentinel_product_dir)]
            val = subprocess.check_output(cmd, stderr=subprocess.STDOUT, shell=True, universal_newlines=True)
            corrected_images = glob.glob(f"*2A_{date}*_T{tile}_*.SAFE/GRANULE/*/IMG_DATA/R10m/*B0[48]*.jp2")
            print(f'Atmospheric correction finished {val}')
        except subprocess.CalledProcessError as e:
            print(e.returncode)
            print(e.output)
            print(e.stderr)
            raise(e)


    # Translate bands in .jp2 to GeoTiff format
    band_files = []
    band4 = glob.glob(os.path.join(tmpdir, '*L2A_{}*_T{}*.SAFE/GRANULE/*/IMG_DATA/R10m/*B04*'.format(date, tile))).pop()
    band8 = glob.glob(os.path.join(tmpdir, '*L2A_{}*_T{}*.SAFE/GRANULE/*/IMG_DATA/R10m/*B08*'.format(date, tile))).pop()

    if band4 is not None and band8 is not None:
        band4_tiff_file = f"{band4[band4.rfind('/')+1:band4.rfind('.')]}.tif"
        band8_tiff_file = f"{band8[band8.rfind('/') + 1:band8.rfind('.')]}.tif"
        jp2_to_cog(band4)
        jp2_to_cog(band8)
        band_files.append(band4_tiff_file)
        band_files.append(band8_tiff_file)
    
    print(band_files)

    # Merge both bands into a single geotiff
    combined_geotiff_key = band_files[0][0:22] + '_COMBINED.tif'
    with rasterio.open(band_files[0]) as src:
        profile = src.profile
        profile.update(count=len(band_files))

    with rasterio.open(combined_geotiff_key, 'w', **profile) as dst:
        for i, band_file in enumerate(band_files):
            with rasterio.open(band_file) as src:
                dst.write(src.read(1), i + 1)

    # Upload generated files to Cloud Storage
    with open(combined_geotiff_key, 'rb') as combined_geotiff_f:
        storage.put_object(bucket=STORAGE_BUCKET, key=combined_geotiff_key, body=combined_geotiff_f)
    product_meta_key = combined_geotiff_key + '.meta.json'
    storage.put_object(bucket=STORAGE_BUCKET, key=product_meta_key, body=json.dumps(product))

    return combined_geotiff_key

# %%
lithops_k8s = lithops.FunctionExecutor(backend='k8s', runtime="tfmurv/lithops-k8s-geospatial", storage="ceph", workers=1)
# Out:
# 2021-07-26 11:22:48,269 [INFO] lithops.config -- Lithops v2.3.6.dev0
# 2021-07-26 11:22:48,272 [DEBUG] lithops.config -- Loading configuration from /home/jovyan/work/.lithops_config
# 2021-07-26 11:22:48,282 [DEBUG] lithops.config -- Loading Serverless backend module: k8s
# 2021-07-26 11:22:48,284 [DEBUG] lithops.config -- Loading Storage backend module: ceph
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-32-f0a2a55bd38c> in <module>
# ----> 1 lithops_k8s = lithops.FunctionExecutor(backend='k8s', runtime="tfmurv/lithops-k8s-geospatial", storage="ceph", workers=1)
#
# /opt/conda/lib/python3.8/site-packages/lithops/executors.py in __init__(self, mode, config, backend, storage, runtime, runtime_memory, monitoring, workers, remote_invoker, log_level)
#      98             config_ow['lithops']['monitoring'] = monitoring
#      99
# --> 100         self.config = default_config(copy.deepcopy(config), config_ow)
#     101
#     102         self.executor_id = create_executor_id()
#
# /opt/conda/lib/python3.8/site-packages/lithops/config.py in default_config(config_data, config_overwrite)
#     230         config_data['lithops']['monitoring'] = constants.MONITORING_DEFAULT
#     231
# --> 232     config_data = default_storage_config(config_data)
#     233
#     234     if config_data['lithops']['storage'] == constants.LOCALHOST and mode != constants.LOCALHOST:
#
# /opt/conda/lib/python3.8/site-packages/lithops/config.py in default_storage_config(config_data, backend)
#     262     logger.debug("Loading Storage backend module: {}".format(sb))
#     263     sb_config = importlib.import_module('lithops.storage.backends.{}.config'.format(sb))
# --> 264     sb_config.load_config(config_data)
#     265
#     266     return config_data
#
# /opt/conda/lib/python3.8/site-packages/lithops/storage/backends/ceph/config.py in load_config(config_data)
#      26         if param not in config_data['ceph']:
#      27             msg = f"'{param}' is mandatory under 'ceph' section of the configuration"
# ---> 28             raise Exception(msg)
#      29
#      30     if not config_data['ceph']['endpoint'].startswith('http'):
#
# Exception: 'secret_key' is mandatory under 'ceph' section of the configuration

# %%
extra_env = {'SENTINEL_USERNAME': SENTINEL_USERNAME,
             'SENTINEL_PASSWORD': SENTINEL_PASSWORD}

lithops_k8s.map(perform_atmospheric_correction, geojson_products["features"], extra_env=extra_env, chunksize=len(geojson_products["features"]))
# Out:
# 2021-07-26 11:21:21,438 [INFO] lithops.invokers -- ExecutorID ec3c4f-4 | JobID M000 - Selected Runtime: tfmurv/lithops-k8s-geospatial - 256MB
# 2021-07-26 11:21:21,440 [DEBUG] lithops.storage.storage -- Runtime metadata not found in local cache. Retrieving it from storage
# 2021-07-26 11:21:21,442 [DEBUG] lithops.storage.storage -- Trying to download runtime metadata from: ceph://lithops-cloudbutton/lithops.runtimes/2.3.6.dev0/k8s/default/tfmurv--lithops-k8s-geospatial--256mb.meta.json
# 2021-07-26 11:21:21,463 [DEBUG] lithops.storage.storage -- Runtime metadata not found in storage
# 2021-07-26 11:21:21,464 [INFO] lithops.invokers -- Runtime tfmurv/lithops-k8s-geospatial with 256MB is not yet installed
# 2021-07-26 11:21:21,465 [INFO] lithops.serverless.backends.k8s.k8s -- Extracting Python modules from: tfmurv/lithops-k8s-geospatial
# 2021-07-26 11:21:21,558 [DEBUG] lithops.serverless.backends.k8s.k8s -- Waiting for runtime metadata
# 2021-07-26 11:21:21,571 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:21,957 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:31,577 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:36,658 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:36,696 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:36,726 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:36,746 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:36,776 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:36,803 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:36,831 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:36,859 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:36,889 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:36,917 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:36,946 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:36,977 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,006 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,038 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,060 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,085 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,112 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,140 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,164 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,183 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,206 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,236 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,265 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,289 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,309 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,332 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,354 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,385 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,413 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,436 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,459 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,488 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,515 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,539 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,561 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,588 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,613 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,645 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,675 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,699 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,730 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,752 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,775 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,798 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,827 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,856 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,884 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,909 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,932 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,961 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:37,992 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,016 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,047 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,073 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,098 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,129 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,156 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,183 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,212 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,240 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,270 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,296 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,327 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,352 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,379 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,411 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,438 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,468 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,500 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,533 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,556 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,579 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,610 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,640 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,663 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,688 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,711 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,734 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,757 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,781 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,809 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,834 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,864 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,889 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,921 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,951 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:38,981 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,005 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,030 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,057 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,082 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,115 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,141 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,169 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,197 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,218 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,241 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,278 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,313 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,343 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,371 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,402 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,430 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,451 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,474 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,498 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,529 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,550 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,573 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,592 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,620 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,644 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,671 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,695 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,724 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,751 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,781 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,810 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,834 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,862 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,888 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,917 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,946 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,972 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:39,998 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,030 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,062 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,089 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,118 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,140 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,163 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,187 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,210 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,240 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,267 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,293 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,324 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,352 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,386 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,417 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,443 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,461 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,484 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,505 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,528 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,553 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,575 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,602 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,625 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,651 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,681 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,707 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,731 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,759 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,784 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,806 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,837 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,865 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,887 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,911 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,936 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,960 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:40,990 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,012 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,043 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,069 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,095 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,124 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,149 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,176 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,201 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,228 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,253 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,276 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,300 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,331 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,362 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,387 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,412 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,438 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,462 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,486 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,510 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,533 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,559 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,578 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,606 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,639 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,666 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,687 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,716 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,742 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,763 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,787 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,810 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,836 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,863 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,891 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,919 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,941 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:41,975 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,008 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,029 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,052 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,076 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,110 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,138 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,167 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,198 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,228 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,257 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,279 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,300 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,325 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,356 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,391 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,422 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,452 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,481 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,501 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,536 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,569 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,598 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,631 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,660 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,683 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,706 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,728 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,752 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,776 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,798 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,822 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,846 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,872 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,895 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,920 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,957 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:42,990 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,021 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,047 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,069 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,091 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,115 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,142 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,175 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,207 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,236 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,262 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,295 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,320 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,344 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,369 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,394 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,417 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,447 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,476 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,507 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,532 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,550 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,572 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,594 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,618 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,640 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,663 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,688 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,710 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,737 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,761 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,786 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,809 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,832 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,862 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,892 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,917 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,943 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,972 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:43,996 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,021 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,052 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,076 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,099 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,120 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,145 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,169 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,195 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,222 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,244 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,271 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,304 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,341 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,368 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,386 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,405 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,423 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,446 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,469 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,495 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,520 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,548 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,575 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,600 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,629 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,651 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,680 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,706 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,733 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,763 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,792 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,818 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,844 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,868 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,892 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,915 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,940 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,962 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:44,985 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,010 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,037 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,058 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,077 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,099 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,127 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,150 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,174 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,197 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,227 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,251 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,274 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,297 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,323 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,347 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,369 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,389 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,411 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,435 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,457 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,481 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,501 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,538 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,564 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,588 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,616 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,646 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,678 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,704 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,724 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,749 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,782 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,808 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,838 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,867 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,891 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,921 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,948 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:45,971 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,000 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,026 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,048 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,067 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,093 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,117 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,141 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,166 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,188 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,214 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,242 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,270 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,298 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,329 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,352 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,379 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,406 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,434 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,456 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,475 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,504 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,528 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,551 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,575 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,602 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,632 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,667 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,695 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,722 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,754 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,777 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,795 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,820 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,852 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,876 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,904 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,931 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,960 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:46,987 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,012 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,045 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,074 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,101 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,120 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,146 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,165 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,190 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,221 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,252 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,283 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,315 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,344 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,372 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,395 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,421 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,449 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,477 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,503 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,533 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,558 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,579 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,603 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,625 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,653 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,682 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,707 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,734 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,764 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,783 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,803 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,829 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,858 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,888 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,910 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,930 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,952 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,971 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:47,992 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,015 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,040 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,061 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,082 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,105 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,129 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,156 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,180 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,203 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,228 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,252 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,276 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,301 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,331 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,359 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,384 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,406 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,430 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,453 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,473 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,503 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,530 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,553 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,575 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,607 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,635 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,665 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,695 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,726 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,756 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,782 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,805 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,828 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,851 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,882 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,906 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,930 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,965 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:48,995 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,022 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,048 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,065 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,090 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,119 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,146 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,171 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,198 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,226 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,253 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,281 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,313 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,337 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,369 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,394 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,417 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,447 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,478 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,496 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,521 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,544 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,570 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,602 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,628 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,661 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,691 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,715 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,740 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,764 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,789 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,815 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,842 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,865 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,887 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,914 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,937 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,961 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:49,985 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,008 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,036 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,058 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,082 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,105 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,122 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,140 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,162 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,199 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,232 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,257 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,279 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,305 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,334 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,355 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,380 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,405 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,431 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,464 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,493 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,516 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,538 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,558 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,586 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,615 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,647 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,678 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,707 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,735 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,759 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,781 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,806 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,830 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,853 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,878 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,904 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,933 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,962 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:50,984 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,007 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,039 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,058 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,080 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,100 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,122 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,145 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,165 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,187 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,210 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,236 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,265 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,294 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,327 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,355 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,387 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,413 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,437 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,457 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,480 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,504 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,527 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,551 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,575 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,598 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,622 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,645 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,665 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,691 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,715 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,741 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,762 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,808 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,840 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,868 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,890 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,907 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,925 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,945 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,964 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:51,984 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,007 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,030 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,055 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,073 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,094 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,122 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,145 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,163 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,186 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,207 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,235 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,253 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,282 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,308 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,332 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,358 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,383 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,412 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,441 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,464 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,489 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,512 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,534 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,560 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,592 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,621 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,639 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,662 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,692 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,711 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,734 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,752 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,780 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:21:52,803 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# ...
# 2021-07-26 11:22:10,607 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:10,632 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:10,664 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:10,695 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:10,722 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:10,748 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:10,775 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:10,802 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:10,827 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:10,856 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:10,886 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:10,917 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:10,946 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:10,969 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:10,993 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,017 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,043 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,067 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,095 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,117 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,140 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,167 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,197 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,229 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,254 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,283 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,309 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,341 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,368 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,395 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,424 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,452 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,478 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,507 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,529 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,551 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,574 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,603 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,626 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,652 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,675 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,698 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,721 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,745 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,768 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,795 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,820 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,848 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,871 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,892 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,919 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,949 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:11,977 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,003 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,037 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,056 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,079 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,103 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,128 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,154 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,178 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,199 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,219 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,245 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,268 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,287 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,305 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,324 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,346 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,365 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,386 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,409 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,434 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,459 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,483 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,508 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,533 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,554 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,579 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,601 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,633 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,663 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,684 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,711 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,736 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,759 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,784 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,807 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,839 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,862 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,885 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,907 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,929 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,957 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:12,979 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,001 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,023 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,044 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,063 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,083 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,101 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,123 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,150 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,179 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,203 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,226 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,251 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,275 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,298 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,326 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,357 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,383 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,407 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,439 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,466 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,491 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,513 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,535 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,553 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,575 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,610 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,642 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,667 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,696 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,721 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,753 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,783 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,816 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,839 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,866 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,894 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,922 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,948 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:13,973 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:14,004 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:14,033 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:14,056 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:14,083 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:14,107 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:14,131 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:14,159 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:14,193 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:14,224 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:14,246 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:14,274 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:14,303 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:14,333 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:14,364 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:14,384 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:14,408 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:14,436 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:14,465 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:14,494 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:14,523 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:14,544 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# 2021-07-26 11:22:14,566 [DEBUG] lithops.serverless.backends.k8s.k8s -- ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-dc207c93f672> in <module>
#       2              'SENTINEL_PASSWORD': SENTINEL_PASSWORD}
#       3
# ----> 4 lithops_k8s.map(perform_atmospheric_correction, geojson_products["features"], extra_env=extra_env, chunksize=len(geojson_products["features"]))
#
# /opt/conda/lib/python3.8/site-packages/lithops/executors.py in map(self, map_function, map_iterdata, chunksize, worker_processes, extra_args, extra_env, runtime_memory, chunk_size, chunk_n, obj_chunk_size, obj_chunk_number, timeout, invoke_pool_threads, include_modules, exclude_modules)
#     232         self.last_call = 'map'
#     233
# --> 234         runtime_meta = self.invoker.select_runtime(job_id, runtime_memory)
#     235
#     236         job = create_map_job(config=self.config,
#
# /opt/conda/lib/python3.8/site-packages/lithops/invokers.py in select_runtime(self, job_id, runtime_memory)
#     120             msg = msg+' with {}MB'.format(runtime_memory) if runtime_memory else msg
#     121             logger.info(msg+' is not yet installed')
# --> 122             runtime_meta = self.compute_handler.create_runtime(self.runtime_name, runtime_memory, runtime_timeout)
#     123             runtime_meta['runtime_timeout'] = runtime_timeout
#     124             self.internal_storage.put_runtime_meta(runtime_key, runtime_meta)
#
# /opt/conda/lib/python3.8/site-packages/lithops/serverless/serverless.py in create_runtime(self, runtime_name, memory, timeout)
#      71         return: the name of the runtime
#      72         """
# ---> 73         return self.backend.create_runtime(runtime_name, memory, timeout=timeout)
#      74
#      75     def delete_runtime(self, runtime_name, memory):
#
# /opt/conda/lib/python3.8/site-packages/lithops/serverless/backends/k8s/k8s.py in create_runtime(self, docker_image_name, memory, timeout)
#     219
#     220         self._create_container_registry_secret()
# --> 221         runtime_meta = self._generate_runtime_meta(docker_image_name)
#     222
#     223         return runtime_meta
#
# /opt/conda/lib/python3.8/site-packages/lithops/serverless/backends/k8s/k8s.py in _generate_runtime_meta(self, docker_image_name)
#     423             try:
#     424                 w = watch.Watch()
# --> 425                 for event in w.stream(self.batch_api.list_namespaced_job,
#     426                                       namespace=self.namespace,
#     427                                       field_selector="metadata.name={0}".format(modules_job_name),
#
# /opt/conda/lib/python3.8/site-packages/kubernetes/watch/watch.py in stream(self, func, *args, **kwargs)
#     161                     # return raw string when we are streaming log
#     162                     if watch_arg == "watch":
# --> 163                         event = self.unmarshal_event(line, return_type)
#     164                         if isinstance(event, dict) \
#     165                                 and event['type'] == 'ERROR':
#
# /opt/conda/lib/python3.8/site-packages/kubernetes/watch/watch.py in unmarshal_event(self, data, return_type)
#      95
#      96     def unmarshal_event(self, data, return_type):
# ---> 97         js = json.loads(data)
#      98         js['raw_object'] = js['object']
#      99         if return_type and js['type'] != 'ERROR':
#
# /opt/conda/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# /opt/conda/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /opt/conda/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     351         """
#     352         try:
# --> 353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
#     355             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# KeyboardInterrupt:

# %%
combined_keys = lithops_k8s.get_result()
print(combined_keys)
# Out:
# 2021-07-26 10:57:16,968 [DEBUG] lithops.executors -- ExecutorID ec3c4f-2 Finished getting results
# []

# %% [markdown]
# ## NDVI Computation using Serverless Lithops

# %% [markdown]
# Now we will calculate NDVI index of tiles tha thave been downloaded and pre-processed before.
#
# This process can be executed in parallel (for every tile) and in serverless functions.

# %%
lithops_serverless = lithops.ServerlessExecutor(runtime='cloudbuttonans/geospatial-runtime:3.7-v4',
                                                runtime_memory=2048, log_level='DEBUG')

# %%
# debug
# combined_keys = ['T30SXG_20201229T110451_COMBINED.tif']

# %%
def ndvi(combined_key, storage):
    tmpdir = tempfile.gettempdir()
    dat = storage.get_object(bucket=STORAGE_BUCKET, key=combined_key, stream=True)
    out = os.path.join(tmpdir, 'out.tif')

    with rasterio.open(dat) as src:
        profile = src.profile
        profile.update(dtype='float32')
        profile.update(count=1)
        with rasterio.open(out, 'w', **profile) as dst:
            for _, window in src.block_windows(1):
                red = src.read(1, window=window).astype('float32')
                nir = src.read(2, window=window).astype('float32')
                ndvi = (np.where((nir + red) == 0., 0,
                                 (nir - red) / (nir + red))).astype('float32')
                dst.write(ndvi, 1, window=window)

    prefix = combined_key.rsplit('_', 1)[0]
    output_key = prefix + '_NDVI.tif'
    with open(out, 'rb') as output_f:
        storage.put_object(bucket=STORAGE_BUCKET, key=output_key, body=output_f)

    return output_key

# %%
lithops_serverless.map(ndvi, combined_keys, timeout=60)

# %%
ndvi_keys = lithops_serverless.get_result()
ndvi_keys

# %%
# debug
# ndvi_keys = ['T30SXG_20201229T110451_NDVI.tif']

# %%
tile_select = notebook_utils.pick_tile(ndvi_keys)

# %%
obj = cloud_storage.get_object(bucket=STORAGE_BUCKET, key=tile_select.value, stream=True)

fig, axs = plt.subplots(figsize=(20,15))

with rasterio.open(obj) as src:
#     ij, window = random.choice(list(src.block_windows()))
#     arr = src.read(1, window=window)
    arr = src.read(1)
    plt.imshow(arr)
